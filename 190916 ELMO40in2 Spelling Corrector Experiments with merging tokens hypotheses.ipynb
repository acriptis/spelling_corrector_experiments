# %%
import pprint
import numpy as np
from spelling_correction_models.elmo_40in_spelling_corrector.elmo_40in2_spelling_corrector import ELMO40in2SpellingCorrector
from copy import deepcopy
# Out:
# /home/alx/Cloud/spell_corr/py_spelling_corrector
# [nltk_data] Downloading package punkt to /home/alx/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/alx/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to /home/alx/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /home/alx/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING: Logging before flag parsing goes to stderr.
# W0917 17:27:44.420856 139820266997568 deprecation_wrapper.py:119] From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/bilm/training.py:21: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0917 17:27:44.421459 139820266997568 deprecation_wrapper.py:119] From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/bilm/training.py:21: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.

# %%
elmo40in = ELMO40in2SpellingCorrector()
# Out:
# Using TensorFlow backend.
# Init LetterCaser.
# Init language_model.
# 2019-09-17 17:27:48.56 WARNING in 'tensorflow'['deprecation_wrapper'] at line 119: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/deeppavlov-0.1.6-py3.6.egg/deeppavlov/models/bidirectional_lms/elmo/utils.py:40: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2019-09-17 17:27:48.57 WARNING in 'tensorflow'['deprecation_wrapper'] at line 119: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/deeppavlov-0.1.6-py3.6.egg/deeppavlov/models/bidirectional_lms/elmo/utils.py:41: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-09-17 17:27:48.79 WARNING in 'tensorflow'['deprecation_wrapper'] at line 119: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/deeppavlov-0.1.6-py3.6.egg/deeppavlov/models/bidirectional_lms/elmo/utils.py:43: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# 2019-09-17 17:27:48.80 WARNING in 'tensorflow'['deprecation_wrapper'] at line 119: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/bilm/training.py:153: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2019-09-17 17:27:48.99 WARNING in 'tensorflow'['deprecation_wrapper'] at line 119: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/bilm/training.py:158: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# 2019-09-17 17:27:48.116 WARNING in 'tensorflow'['deprecation_wrapper'] at line 119: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/bilm/training.py:211: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 2019-09-17 17:27:48.118 WARNING in 'tensorflow'['deprecation'] at line 506: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py:180: calling squeeze (from tensorflow.python.ops.array_ops) with squeeze_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead
# 2019-09-17 17:27:48.300 WARNING in 'tensorflow'['deprecation'] at line 323: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/bilm/training.py:372: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# 2019-09-17 17:27:48.301 WARNING in 'tensorflow'['deprecation_wrapper'] at line 119: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/bilm/training.py:386: The name tf.nn.rnn_cell.ResidualWrapper is deprecated. Please use tf.compat.v1.nn.rnn_cell.ResidualWrapper instead.
#
# 2019-09-17 17:27:48.302 WARNING in 'tensorflow'['deprecation'] at line 323: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/bilm/training.py:396: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# 2019-09-17 17:27:48.320 WARNING in 'tensorflow'['deprecation'] at line 323: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/bilm/training.py:410: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# 2019-09-17 17:27:48.452 WARNING in 'tensorflow'['deprecation'] at line 506: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2019-09-17 17:27:48.458 WARNING in 'tensorflow'['deprecation'] at line 506: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/tensorflow/python/ops/rnn_cell_impl.py:961: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# USING SKIP CONNECTIONS
# 2019-09-17 17:27:48.946 WARNING in 'tensorflow'['deprecation_wrapper'] at line 119: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/deeppavlov-0.1.6-py3.6.egg/deeppavlov/models/bidirectional_lms/elmo/utils.py:52: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# 2019-09-17 17:27:48.973 WARNING in 'tensorflow'['deprecation'] at line 323: From /home/alx/Cloud/dns/.venv3/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2019-09-17 17:27:48.974 INFO in 'tensorflow'['saver'] at line 1280: Restoring parameters from /home/alx/Cloud/spell_corr/py_spelling_corrector/bidirectional_lms/elmo_ru_news/model.ckpt-1327437
# Init spelling_correction_candidates_generator.
# Initialization Completed.

# %%
sentence = "мамо мы ла рабу"

# %%
preprocessed_sentence = elmo40in.preprocess_sentence(sentence)
preprocessed_sentence
# Out:
# 'мамо мы ла рабу'

# %%
# tok_wrapped = elmo40in.lm.tokenize_sentence(sentence)
elmo_data = elmo40in.lm.analyze_sentence(sentence)

# %%
analysis_dict = elmo40in.elmo_analysis_with_probable_candidates_reduction_dict_out(preprocessed_sentence)
analysis_dict
# Out:
# {'input_sentence': 'мамо мы ла рабу',
#  'tokenized_input_sentence': ['<S>', 'мамо', 'мы', 'ла', 'рабу', '</S>'],
#  'word_substitutions_candidates': [{'tok_idx': 0, 'top_k_candidates': []},
#   {'tok_idx': 1,
#    'top_k_candidates': [{'advantage': 1.4654415043774653, 'token_str': 'мало'},
#     {'advantage': 0.8290032949621251, 'token_str': 'мама'},
#     {'advantage': 0.5788053066965881, 'token_str': 'мимо'},
#     {'advantage': 0.0682681172786106, 'token_str': 'маме'},
#     {'advantage': 0.0, 'token_str': 'мамо'}]},
#   {'tok_idx': 2, 'top_k_candidates': [{'advantage': 0.0, 'token_str': 'мы'}]},
#   {'tok_idx': 3,
#    'top_k_candidates': [{'advantage': 7.909878868209844, 'token_str': 'на'},
#     {'advantage': 6.869433134510696, 'token_str': 'за'},
#     {'advantage': 5.609125288265215, 'token_str': 'а'},
#     {'advantage': 4.591302278044582, 'token_str': 'да'},
#     {'advantage': 4.534746617501758, 'token_str': 'ли'},
#     {'advantage': 2.2575124093097294, 'token_str': 'зла'},
#     {'advantage': 2.1699851412306375, 'token_str': 'шла'},
#     {'advantage': 2.116203203263707, 'token_str': 'ка'},
#     {'advantage': 1.5435339098199536, 'token_str': 'ль'},
#     {'advantage': 1.3843852873087856, 'token_str': 'ва'},
#     {'advantage': 1.3567950485204125, 'token_str': 'та'},
#     {'advantage': 1.1416171799843715, 'token_str': 'л'},
#     {'advantage': 0.894093864484022, 'token_str': 'ма'},
#     {'advantage': 0.8312294913850709, 'token_str': 'ела'},
#     {'advantage': 0.6130232420520505, 'token_str': 'ля'},
#     {'advantage': 0.5685809466324443, 'token_str': 'лаю'},
#     {'advantage': 0.2392642375027938, 'token_str': 'ло'},
#     {'advantage': 8.881784197001252e-16, 'token_str': 'ла'}]},
#   {'tok_idx': 4,
#    'top_k_candidates': [{'advantage': 1.338874848056081, 'token_str': 'рабы'},
#     {'advantage': 1.0757820984060213, 'token_str': 'бабу'},
#     {'advantage': 1.0092864240096588, 'token_str': 'разу'},
#     {'advantage': 0.9318240256975585, 'token_str': 'раба'},
#     {'advantage': 0.6805089544958989, 'token_str': 'рыбу'},
#     {'advantage': 0.2985749735125065, 'token_str': 'раб'},
#     {'advantage': 0.0, 'token_str': 'рабу'}]},
#   {'tok_idx': 5,
#    'top_k_candidates': [{'advantage': 0.0, 'token_str': '</S>'}]}]}

# %%
merged_tokens_hypotheses_dict = elmo40in.generate_Nto1_hypotheses(analysis_dict['tokenized_input_sentence'], elmo_data)
merged_tokens_hypotheses_dict
# Out:
# Skipping OOV hypothesis: мамомы
# Merged TokenHypothesis is in dictionary!
# Skipping OOV hypothesis: ларабу
# [{'tok_idx': (2, 3),
#   'tok_idx_start': 2,
#   'tok_idx_fin': 3,
#   'top_k_candidates': [{'token_str': 'мыла',
#     'token_merges': 1,
#     'error_score': -4.0,
#     'lm_scores_list': array([-5.04645906, -7.16744132]),
#     'base_scores': array([[-6.6675347 , -6.32782808],
#            [-6.6675347 , -6.32782808]]),
#     'summated_base_scores': array([-13.3350694 , -12.65565617]),
#     'advantage': 5.7768251961428625}]}]

# %%
analysis_dict['word_substitutions_candidates'] += merged_tokens_hypotheses_dict
analysis_dict
# Out:
# {'input_sentence': 'мамо мы ла рабу',
#  'tokenized_input_sentence': ['<S>', 'мамо', 'мы', 'ла', 'рабу', '</S>'],
#  'word_substitutions_candidates': [{'tok_idx': 0, 'top_k_candidates': []},
#   {'tok_idx': 1,
#    'top_k_candidates': [{'advantage': 1.4654415043774653, 'token_str': 'мало'},
#     {'advantage': 0.8290032949621251, 'token_str': 'мама'},
#     {'advantage': 0.5788053066965881, 'token_str': 'мимо'},
#     {'advantage': 0.0682681172786106, 'token_str': 'маме'},
#     {'advantage': 0.0, 'token_str': 'мамо'}]},
#   {'tok_idx': 2, 'top_k_candidates': [{'advantage': 0.0, 'token_str': 'мы'}]},
#   {'tok_idx': 3,
#    'top_k_candidates': [{'advantage': 7.909878868209844, 'token_str': 'на'},
#     {'advantage': 6.869433134510696, 'token_str': 'за'},
#     {'advantage': 5.609125288265215, 'token_str': 'а'},
#     {'advantage': 4.591302278044582, 'token_str': 'да'},
#     {'advantage': 4.534746617501758, 'token_str': 'ли'},
#     {'advantage': 2.2575124093097294, 'token_str': 'зла'},
#     {'advantage': 2.1699851412306375, 'token_str': 'шла'},
#     {'advantage': 2.116203203263707, 'token_str': 'ка'},
#     {'advantage': 1.5435339098199536, 'token_str': 'ль'},
#     {'advantage': 1.3843852873087856, 'token_str': 'ва'},
#     {'advantage': 1.3567950485204125, 'token_str': 'та'},
#     {'advantage': 1.1416171799843715, 'token_str': 'л'},
#     {'advantage': 0.894093864484022, 'token_str': 'ма'},
#     {'advantage': 0.8312294913850709, 'token_str': 'ела'},
#     {'advantage': 0.6130232420520505, 'token_str': 'ля'},
#     {'advantage': 0.5685809466324443, 'token_str': 'лаю'},
#     {'advantage': 0.2392642375027938, 'token_str': 'ло'},
#     {'advantage': 8.881784197001252e-16, 'token_str': 'ла'}]},
#   {'tok_idx': 4,
#    'top_k_candidates': [{'advantage': 1.338874848056081, 'token_str': 'рабы'},
#     {'advantage': 1.0757820984060213, 'token_str': 'бабу'},
#     {'advantage': 1.0092864240096588, 'token_str': 'разу'},
#     {'advantage': 0.9318240256975585, 'token_str': 'раба'},
#     {'advantage': 0.6805089544958989, 'token_str': 'рыбу'},
#     {'advantage': 0.2985749735125065, 'token_str': 'раб'},
#     {'advantage': 0.0, 'token_str': 'рабу'}]},
#   {'tok_idx': 5,
#    'top_k_candidates': [{'advantage': 0.0, 'token_str': '</S>'}]},
#   {'tok_idx': (2, 3),
#    'tok_idx_start': 2,
#    'tok_idx_fin': 3,
#    'top_k_candidates': [{'token_str': 'мыла',
#      'token_merges': 1,
#      'error_score': -4.0,
#      'lm_scores_list': array([-5.04645906, -7.16744132]),
#      'base_scores': array([[-6.6675347 , -6.32782808],
#             [-6.6675347 , -6.32782808]]),
#      'summated_base_scores': array([-13.3350694 , -12.65565617]),
#      'advantage': 5.7768251961428625}]}]}

# %%
def estimate_the_best_s_hypotheses(data_analysis_dict):
    hypotheses_hub = HypothesesHub()
    for current_token_idx, each_tok in enumerate(data_analysis_dict['tokenized_input_sentence']):
        if current_token_idx==0:
            # skip the first token which is <s>
            continue
        if current_token_idx==len(data_analysis_dict['tokenized_input_sentence'])-1:
            # skip the last token which is </s>
            continue
        print(each_tok)
        #  suffixes_hypotheses = data_analysis_dict['word_substitutions_candidates'].filter(start_idx=current_token_idx)
        suffixes_hypotheses = SCAnalysisDictManager.filter_by_start_index(
            data_anal_dict=data_analysis_dict, start_index=current_token_idx)
        print("suffixes_hypotheses")
        print(suffixes_hypotheses)
        # suffixes hypotheses is a list of dicts with hypotheses that start at index: current_token_idx and finish at current_token_idx or later        
        # expect that each s_hypothesis in hub has finish index (pointer of the final index position).
        # Ex. suffixes_hypotheses: 
        #         [{'tok_idx': 1,
        #            'top_k_candidates': [{'advantage': 0.0, 'token_str': 'мамо'},
        #             {'advantage': 0.8290032949621251, 'token_str': 'мама'},
        #             {'advantage': 0.0682681172786106, 'token_str': 'маме'},
        #             {'advantage': 1.4654415043774653, 'token_str': 'мало'},
        #             {'advantage': 0.5788053066965881, 'token_str': 'мимо'}]},

        #             {'tok_idx': (1, 3),
        #              'tok_idx_start': 2,
        #              'tok_idx_fin': 3,
        #              'top_k_candidates': [{'token_str': 'мыла',
        #                                    'token_merges': 1,
        #                                    'error_score': -4.0,
        #                                    'lm_scores_list': array([-4.99906474, -6.26263737]),
        #                                    'summated_base_scores': array([-13.19048357, -11.76141742]),
        #                                    'advantage': 9.690198885299584}]}
        #         ]
        
        # TODO implement method:
        hypotheses_hub = hypotheses_hub.fork_for_suffixes_segment_hypotheses(suffixes_hypotheses)
        print(len(hypotheses_hub))
        # TODO prune hypotheses that has finish_index==current_token_idx, but dont prune hypotheses that are longer
    # TODO implement method:
    the_best_sentence_hypothesis = hypotheses_hub.find_top_k(top_k=1)
    return the_best_sentence_hypothesis

class SCAnalysisDictManager():
    """
    Class which wraps operations for dict with sentence analysis of spelling corrector. 
    
    Example artifact:
    {'input_sentence': 'мамо мы ла рабу',
     'tokenized_input_sentence': ['<S>', 'мамо', 'мы', 'ла', 'рабу', '</S>'],
     'word_substitutions_candidates': [{'tok_idx': 0, 'top_k_candidates': []},
      {'tok_idx': 1,
       'top_k_candidates': [{'advantage': 0.0, 'token_str': 'мамо'},
        {'advantage': 0.8290032949621251, 'token_str': 'мама'},
        {'advantage': 0.0682681172786106, 'token_str': 'маме'},
        {'advantage': 1.4654415043774653, 'token_str': 'мало'},
        {'advantage': 0.5788053066965881, 'token_str': 'мимо'}]},
      {'tok_idx': 2, 'top_k_candidates': [{'advantage': 0.0, 'token_str': 'мы'}]},
      {'tok_idx': 3,
       'top_k_candidates': [{'advantage': 8.881784197001252e-16,
         'token_str': 'ла'},
        {'advantage': 1.1416171799843715, 'token_str': 'л'},
        {'advantage': 4.534746617501758, 'token_str': 'ли'},
        {'advantage': 0.2392642375027938, 'token_str': 'ло'},
        {'advantage': 1.5435339098199536, 'token_str': 'ль'},
        {'advantage': 0.6130232420520505, 'token_str': 'ля'},
        {'advantage': 0.5685809466324443, 'token_str': 'лаю'},
        {'advantage': 5.609125288265215, 'token_str': 'а'},
        {'advantage': 1.3843852873087856, 'token_str': 'ва'},
        {'advantage': 4.591302278044582, 'token_str': 'да'},
        {'advantage': 6.869433134510696, 'token_str': 'за'},
        {'advantage': 2.116203203263707, 'token_str': 'ка'},
        {'advantage': 0.894093864484022, 'token_str': 'ма'},
        {'advantage': 7.909878868209844, 'token_str': 'на'},
        {'advantage': 1.3567950485204125, 'token_str': 'та'},
        {'advantage': 0.8312294913850709, 'token_str': 'ела'},
        {'advantage': 2.2575124093097294, 'token_str': 'зла'},
        {'advantage': 2.1699851412306375, 'token_str': 'шла'}]},
      {'tok_idx': 4,
       'top_k_candidates': [{'advantage': 0.0, 'token_str': 'рабу'},
        {'advantage': 0.2985749735125065, 'token_str': 'раб'},
        {'advantage': 0.9318240256975585, 'token_str': 'раба'},
        {'advantage': 1.338874848056081, 'token_str': 'рабы'},
        {'advantage': 1.0092864240096588, 'token_str': 'разу'},
        {'advantage': 0.6805089544958989, 'token_str': 'рыбу'},
        {'advantage': 1.0757820984060213, 'token_str': 'бабу'}]},
      {'tok_idx': 5,
       'top_k_candidates': [{'advantage': 0.0, 'token_str': '</S>'}]},
      {'tok_idx': (2, 3),
       'tok_idx_start': 2,
       'tok_idx_fin': 3,
       'top_k_candidates': [{'token_str': 'мыла',
         'token_merges': 1,
         'error_score': -4.0,
         'lm_scores_list': array([-4.99906474, -6.26263737]),
         'summated_base_scores': array([-13.19048357, -11.76141742]),
         'advantage': 9.690198885299584}]}]}
    """
    @staticmethod
    def filter_by_start_index(data_anal_dict, start_index):
        """Given a dict with data analysis it filters out word spans substitution candidates which start at specific token index 
        (integer measured in input sentence token space)"""
        assert "word_substitutions_candidates" in data_anal_dict
        # results list is a list of dicts of hypotheses sets for particular spans (1token spans and 2-token spans, AS-IS)
        results_list = []
        for each_dict_set_of_candidates in data_anal_dict['word_substitutions_candidates']:
            # here is a complex condition that iteratively checks that substitution candidates dict set starts at 
            # specific token position. Then it filters out the best candidates subset from each set merges that sets and returns a result 
            # of the query.
            # candidate set dict describes set of candidates which can substitute particular span it 
            # may be 1token-1token substitution or may be Ntokens->1token substitution.
            # for the firsts tok_idx key is integer holding the start_index
            # for the latter tok_idx key is tuple holding the start_index and the last index
                        
            if each_dict_set_of_candidates['tok_idx'] == start_index or \
                (isinstance(each_dict_set_of_candidates['tok_idx'], tuple) \
                     and each_dict_set_of_candidates['tok_idx'][0]==start_index):
                results_list.append(each_dict_set_of_candidates)
        
        return results_list
        
class SentenceHypothesis():
    def __init__(self, text):
        # TODO refactor clean code
        if text!="":
            print("SentenceHypothesis must be init with empty string!")
        self.text = ""
#         self.score = np.nan
#         self.lm_score = 0
        # score for error:
#         self.err_score = err_score
#         self.final_score = 0.0
        # token hypotheses of the sentence
        self.token_hypotheses = []
        
        # index of the last token in hypothesis
        self.finish_idx = -1
        # -1 for empty hypothesis and tokens length for other
 
    def calc_advantage_score(self):
        adv_score = 0.0
        for each_token_hypothesis in self.token_hypotheses:
            adv_score+=each_token_hypothesis['advantage']
        return adv_score
    
    def fork_for_each_suffix(self, suffixes_dicts_list):
        """Given a list of suffixes strings it forks the current hypotheses into several
        hypotheses for each suffix.
        
        : suffixes_dicts_list:
        Ex.:
        [
            {'tok_idx': 4,
               'top_k_candidates': [{'advantage': 0.0, 'token_str': 'рабу'},
                                    {'advantage': 0.2985749735125065, 'token_str': 'раб'},
                                    {'advantage': 0.9318240256975585, 'token_str': 'раба'},
                                    {'advantage': 1.338874848056081, 'token_str': 'рабы'},
                                    {'advantage': 1.0092864240096588, 'token_str': 'разу'},
                                    {'advantage': 0.6805089544958989, 'token_str': 'рыбу'},
                                    {'advantage': 1.0757820984060213, 'token_str': 'бабу'}]},
            {'tok_idx': (4, 5),
               'tok_idx_start': 4,
               'tok_idx_fin': 5,
               'top_k_candidates': [{'token_str': 'мыла',
                 'token_merges': 1,
                 'error_score': -4.0,
                 'lm_scores_list': array([-4.99906474, -6.26263737]),
                 'summated_base_scores': array([-13.19048357, -11.76141742]),
                 'advantage': 9.690198885299584}]}
         ]
        
        """
        hypotheses_list = []
        
        for idx, each_suffix_dict in enumerate(suffixes_dicts_list):
            # iteration over list of dicts with segments-candidates. First dict is a dict with 1token-1token substitution candidates:
            if isinstance(each_suffix_dict['tok_idx'], int):
                start_tok_idx = each_suffix_dict['tok_idx']
            elif isinstance(each_suffix_dict['tok_idx'], tuple):
                start_tok_idx = each_suffix_dict['tok_idx'][0]
            else:
                raise Exception("Wrong format! data: %s" % each_suffix_dict)
                
            for candidate_idx, each_candidate_dict in enumerate(each_suffix_dict['top_k_candidates']):
                # TODO assert that each new candidate has lower advantage
                new_sentence_hypothesis = deepcopy(self)
                # ############################################################
                # add a segment suffix to the sentence hypothesis:
                new_sentence_hypothesis.text += " " + each_candidate_dict['token_str']
                new_sentence_hypothesis.token_hypotheses.append(each_candidate_dict)
                
                # retrieve fin_tok_index from candidate span:
                if isinstance(each_suffix_dict['tok_idx'], int):
                    fin_tok_idx = each_suffix_dict['tok_idx']
                elif isinstance(each_suffix_dict['tok_idx'], tuple):
                    fin_tok_idx = each_suffix_dict['tok_idx'][1]
                    
                new_sentence_hypothesis.finish_idx = fin_tok_idx
                # ############################################################
            
                hypotheses_list.append(new_sentence_hypothesis)

        return hypotheses_list

    def __repr__(self):        
#         if self.final_score!=0:
#             out_text = " score: %f" % self.final_score        
#         else:
#             out_text = " score: %f" % self.total_score()        
        text = "hypothesis: %s" % self.text
        return text
    
class HypothesesHub():
    def __init__(self):
        # init with null hypothesis:
        self.hypotheses = [SentenceHypothesis("")]
    
    def fork_for_suffixes_segment_hypotheses(self, segment_candidates_dicts_list):
        """
        For each hypothesis in the hub it appends all candidates
        :param partial_candidates_dicts_list:
        Ex.: 
        [
            {'tok_idx': 4,
               'top_k_candidates': [{'advantage': 0.0, 'token_str': 'рабу'},
                                    {'advantage': 0.2985749735125065, 'token_str': 'раб'},
                                    {'advantage': 0.9318240256975585, 'token_str': 'раба'},
                                    {'advantage': 1.338874848056081, 'token_str': 'рабы'},
                                    {'advantage': 1.0092864240096588, 'token_str': 'разу'},
                                    {'advantage': 0.6805089544958989, 'token_str': 'рыбу'},
                                    {'advantage': 1.0757820984060213, 'token_str': 'бабу'}]},
            {'tok_idx': (4, 5),
               'tok_idx_start': 4,
               'tok_idx_fin': 5,
               'top_k_candidates': [{'token_str': 'мыла',
                 'token_merges': 1,
                 'error_score': -4.0,
                 'lm_scores_list': array([-4.99906474, -6.26263737]),
                 'summated_base_scores': array([-13.19048357, -11.76141742]),
                 'advantage': 9.690198885299584}]}
         ]
                                    
        

        :return: updated self
        """
        
        # validation that start indexes for candidates dicts are aligned
        assert isinstance(segment_candidates_dicts_list[0]['tok_idx'], int)
        suffixes_start_idx = segment_candidates_dicts_list[0]['tok_idx']
        if len(segment_candidates_dicts_list)>1:
            assert isinstance(segment_candidates_dicts_list[1]['tok_idx'], tuple)
            assert 'tok_idx_start' in segment_candidates_dicts_list[1]
            assert isinstance(segment_candidates_dicts_list[1]['tok_idx_start'], int)
            assert segment_candidates_dicts_list[1]['tok_idx_start']==suffixes_start_idx
        
        new_hypotheses = []
        for each_s_hypothesis in self.hypotheses:
            if each_s_hypothesis.finish_idx < suffixes_start_idx:
                # TODO implement method
                print("each_s_hypothesis.finish_idx < suffixes_start_idx")
                hypos = each_s_hypothesis.fork_for_each_suffix(segment_candidates_dicts_list)
                new_hypotheses += hypos
            else:
                print("each_s_hypothesis.finish_idx > suffixes_start_idx")
                # we have a hypothesis that merged multiple tokens:
                assert each_s_hypothesis.finish_idx >= suffixes_start_idx
                # so add this hypothesis as is (without suffix appending):
                new_hypotheses.append(each_s_hypothesis)
            
        self.hypotheses = new_hypotheses
        return self
    
#     def prune_hypotheses(self, top_k=100):
#         prunes_hypotheses to restricted amount
    
    def find_top_k(self, top_k=-1):
        # TODO implement me
        return self.hypotheses
    
    def __len__(self):
        return len(self.hypotheses)

# %%
hh = HypothesesHub()
print(len(hh))
hh2 = hh.fork_for_suffixes_segment_hypotheses(segment_candidates_dicts_list=[{'tok_idx': 1, 'top_k_candidates': [{'advantage': 1.4654415043774653, 'token_str': 'мало'}, {'advantage': 0.8290032949621251, 'token_str': 'мама'}, {'advantage': 0.5788053066965881, 'token_str': 'мимо'}, {'advantage': 0.0682681172786106, 'token_str': 'маме'}, {'advantage': 0.0, 'token_str': 'мамо'}]}])
len(hh2)
# Out:
# 1
# each_s_hypothesis.finish_idx < suffixes_start_idx
# 5

# %%
the_best_sentence_hypothesis = estimate_the_best_s_hypotheses(analysis_dict)
the_best_sentence_hypothesis
# Out:
# мамо
# suffixes_hypotheses
# [{'tok_idx': 1, 'top_k_candidates': [{'advantage': 1.4654415043774653, 'token_str': 'мало'}, {'advantage': 0.8290032949621251, 'token_str': 'мама'}, {'advantage': 0.5788053066965881, 'token_str': 'мимо'}, {'advantage': 0.0682681172786106, 'token_str': 'маме'}, {'advantage': 0.0, 'token_str': 'мамо'}]}]
# each_s_hypothesis.finish_idx < suffixes_start_idx
# 5
# мы
# suffixes_hypotheses
# [{'tok_idx': 2, 'top_k_candidates': [{'advantage': 0.0, 'token_str': 'мы'}]}, {'tok_idx': (2, 3), 'tok_idx_start': 2, 'tok_idx_fin': 3, 'top_k_candidates': [{'token_str': 'мыла', 'token_merges': 1, 'error_score': -4.0, 'lm_scores_list': array([-5.04645906, -7.16744132]), 'base_scores': array([[-6.6675347 , -6.32782808],
#        [-6.6675347 , -6.32782808]]), 'summated_base_scores': array([-13.3350694 , -12.65565617]), 'advantage': 5.7768251961428625}]}]
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# 10
# ла
# suffixes_hypotheses
# [{'tok_idx': 3, 'top_k_candidates': [{'advantage': 7.909878868209844, 'token_str': 'на'}, {'advantage': 6.869433134510696, 'token_str': 'за'}, {'advantage': 5.609125288265215, 'token_str': 'а'}, {'advantage': 4.591302278044582, 'token_str': 'да'}, {'advantage': 4.534746617501758, 'token_str': 'ли'}, {'advantage': 2.2575124093097294, 'token_str': 'зла'}, {'advantage': 2.1699851412306375, 'token_str': 'шла'}, {'advantage': 2.116203203263707, 'token_str': 'ка'}, {'advantage': 1.5435339098199536, 'token_str': 'ль'}, {'advantage': 1.3843852873087856, 'token_str': 'ва'}, {'advantage': 1.3567950485204125, 'token_str': 'та'}, {'advantage': 1.1416171799843715, 'token_str': 'л'}, {'advantage': 0.894093864484022, 'token_str': 'ма'}, {'advantage': 0.8312294913850709, 'token_str': 'ела'}, {'advantage': 0.6130232420520505, 'token_str': 'ля'}, {'advantage': 0.5685809466324443, 'token_str': 'лаю'}, {'advantage': 0.2392642375027938, 'token_str': 'ло'}, {'advantage': 8.881784197001252e-16, 'token_str': 'ла'}]}]
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx > suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx > suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx > suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx > suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx > suffixes_start_idx
# 95
# рабу
# suffixes_hypotheses
# [{'tok_idx': 4, 'top_k_candidates': [{'advantage': 1.338874848056081, 'token_str': 'рабы'}, {'advantage': 1.0757820984060213, 'token_str': 'бабу'}, {'advantage': 1.0092864240096588, 'token_str': 'разу'}, {'advantage': 0.9318240256975585, 'token_str': 'раба'}, {'advantage': 0.6805089544958989, 'token_str': 'рыбу'}, {'advantage': 0.2985749735125065, 'token_str': 'раб'}, {'advantage': 0.0, 'token_str': 'рабу'}]}]
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# 665
# [hypothesis:  мало мы на рабы,
#  hypothesis:  мало мы на бабу,
#  hypothesis:  мало мы на разу,
#  hypothesis:  мало мы на раба,
#  hypothesis:  мало мы на рыбу,
#  hypothesis:  мало мы на раб,
#  hypothesis:  мало мы на рабу,
#  hypothesis:  мало мы за рабы,
#  hypothesis:  мало мы за бабу,
#  hypothesis:  мало мы за разу,
#  hypothesis:  мало мы за раба,
#  hypothesis:  мало мы за рыбу,
#  hypothesis:  мало мы за раб,
#  hypothesis:  мало мы за рабу,
#  hypothesis:  мало мы а рабы,
#  hypothesis:  мало мы а бабу,
#  hypothesis:  мало мы а разу,
#  hypothesis:  мало мы а раба,
#  hypothesis:  мало мы а рыбу,
#  hypothesis:  мало мы а раб,
#  hypothesis:  мало мы а рабу,
#  hypothesis:  мало мы да рабы,
#  hypothesis:  мало мы да бабу,
#  hypothesis:  мало мы да разу,
#  hypothesis:  мало мы да раба,
#  hypothesis:  мало мы да рыбу,
#  hypothesis:  мало мы да раб,
#  hypothesis:  мало мы да рабу,
#  hypothesis:  мало мы ли рабы,
#  hypothesis:  мало мы ли бабу,
#  hypothesis:  мало мы ли разу,
#  hypothesis:  мало мы ли раба,
#  hypothesis:  мало мы ли рыбу,
#  hypothesis:  мало мы ли раб,
#  hypothesis:  мало мы ли рабу,
#  hypothesis:  мало мы зла рабы,
#  hypothesis:  мало мы зла бабу,
#  hypothesis:  мало мы зла разу,
#  hypothesis:  мало мы зла раба,
#  hypothesis:  мало мы зла рыбу,
#  hypothesis:  мало мы зла раб,
#  hypothesis:  мало мы зла рабу,
#  hypothesis:  мало мы шла рабы,
#  hypothesis:  мало мы шла бабу,
#  hypothesis:  мало мы шла разу,
#  hypothesis:  мало мы шла раба,
#  hypothesis:  мало мы шла рыбу,
#  hypothesis:  мало мы шла раб,
#  hypothesis:  мало мы шла рабу,
#  hypothesis:  мало мы ка рабы,
#  hypothesis:  мало мы ка бабу,
#  hypothesis:  мало мы ка разу,
#  hypothesis:  мало мы ка раба,
#  hypothesis:  мало мы ка рыбу,
#  hypothesis:  мало мы ка раб,
#  hypothesis:  мало мы ка рабу,
#  hypothesis:  мало мы ль рабы,
#  hypothesis:  мало мы ль бабу,
#  hypothesis:  мало мы ль разу,
#  hypothesis:  мало мы ль раба,
#  hypothesis:  мало мы ль рыбу,
#  hypothesis:  мало мы ль раб,
#  hypothesis:  мало мы ль рабу,
#  hypothesis:  мало мы ва рабы,
#  hypothesis:  мало мы ва бабу,
#  hypothesis:  мало мы ва разу,
#  hypothesis:  мало мы ва раба,
#  hypothesis:  мало мы ва рыбу,
#  hypothesis:  мало мы ва раб,
#  hypothesis:  мало мы ва рабу,
#  hypothesis:  мало мы та рабы,
#  hypothesis:  мало мы та бабу,
#  hypothesis:  мало мы та разу,
#  hypothesis:  мало мы та раба,
#  hypothesis:  мало мы та рыбу,
#  hypothesis:  мало мы та раб,
#  hypothesis:  мало мы та рабу,
#  hypothesis:  мало мы л рабы,
#  hypothesis:  мало мы л бабу,
#  hypothesis:  мало мы л разу,
#  hypothesis:  мало мы л раба,
#  hypothesis:  мало мы л рыбу,
#  hypothesis:  мало мы л раб,
#  hypothesis:  мало мы л рабу,
#  hypothesis:  мало мы ма рабы,
#  hypothesis:  мало мы ма бабу,
#  hypothesis:  мало мы ма разу,
#  hypothesis:  мало мы ма раба,
#  hypothesis:  мало мы ма рыбу,
#  hypothesis:  мало мы ма раб,
#  hypothesis:  мало мы ма рабу,
#  hypothesis:  мало мы ела рабы,
#  hypothesis:  мало мы ела бабу,
#  hypothesis:  мало мы ела разу,
#  hypothesis:  мало мы ела раба,
#  hypothesis:  мало мы ела рыбу,
#  hypothesis:  мало мы ела раб,
#  hypothesis:  мало мы ела рабу,
#  hypothesis:  мало мы ля рабы,
#  hypothesis:  мало мы ля бабу,
#  hypothesis:  мало мы ля разу,
#  hypothesis:  мало мы ля раба,
#  hypothesis:  мало мы ля рыбу,
#  hypothesis:  мало мы ля раб,
#  hypothesis:  мало мы ля рабу,
#  hypothesis:  мало мы лаю рабы,
#  hypothesis:  мало мы лаю бабу,
#  hypothesis:  мало мы лаю разу,
#  hypothesis:  мало мы лаю раба,
#  hypothesis:  мало мы лаю рыбу,
#  hypothesis:  мало мы лаю раб,
#  hypothesis:  мало мы лаю рабу,
#  hypothesis:  мало мы ло рабы,
#  hypothesis:  мало мы ло бабу,
#  hypothesis:  мало мы ло разу,
#  hypothesis:  мало мы ло раба,
#  hypothesis:  мало мы ло рыбу,
#  hypothesis:  мало мы ло раб,
#  hypothesis:  мало мы ло рабу,
#  hypothesis:  мало мы ла рабы,
#  hypothesis:  мало мы ла бабу,
#  hypothesis:  мало мы ла разу,
#  hypothesis:  мало мы ла раба,
#  hypothesis:  мало мы ла рыбу,
#  hypothesis:  мало мы ла раб,
#  hypothesis:  мало мы ла рабу,
#  hypothesis:  мало мыла рабы,
#  hypothesis:  мало мыла бабу,
#  hypothesis:  мало мыла разу,
#  hypothesis:  мало мыла раба,
#  hypothesis:  мало мыла рыбу,
#  hypothesis:  мало мыла раб,
#  hypothesis:  мало мыла рабу,
#  hypothesis:  мама мы на рабы,
#  hypothesis:  мама мы на бабу,
#  hypothesis:  мама мы на разу,
#  hypothesis:  мама мы на раба,
#  hypothesis:  мама мы на рыбу,
#  hypothesis:  мама мы на раб,
#  hypothesis:  мама мы на рабу,
#  hypothesis:  мама мы за рабы,
#  hypothesis:  мама мы за бабу,
#  hypothesis:  мама мы за разу,
#  hypothesis:  мама мы за раба,
#  hypothesis:  мама мы за рыбу,
#  hypothesis:  мама мы за раб,
#  hypothesis:  мама мы за рабу,
#  hypothesis:  мама мы а рабы,
#  hypothesis:  мама мы а бабу,
#  hypothesis:  мама мы а разу,
#  hypothesis:  мама мы а раба,
#  hypothesis:  мама мы а рыбу,
#  hypothesis:  мама мы а раб,
#  hypothesis:  мама мы а рабу,
#  hypothesis:  мама мы да рабы,
#  hypothesis:  мама мы да бабу,
#  hypothesis:  мама мы да разу,
#  hypothesis:  мама мы да раба,
#  hypothesis:  мама мы да рыбу,
#  hypothesis:  мама мы да раб,
#  hypothesis:  мама мы да рабу,
#  hypothesis:  мама мы ли рабы,
#  hypothesis:  мама мы ли бабу,
#  hypothesis:  мама мы ли разу,
#  hypothesis:  мама мы ли раба,
#  hypothesis:  мама мы ли рыбу,
#  hypothesis:  мама мы ли раб,
#  hypothesis:  мама мы ли рабу,
#  hypothesis:  мама мы зла рабы,
#  hypothesis:  мама мы зла бабу,
#  hypothesis:  мама мы зла разу,
#  hypothesis:  мама мы зла раба,
#  hypothesis:  мама мы зла рыбу,
#  hypothesis:  мама мы зла раб,
#  hypothesis:  мама мы зла рабу,
#  hypothesis:  мама мы шла рабы,
#  hypothesis:  мама мы шла бабу,
#  hypothesis:  мама мы шла разу,
#  hypothesis:  мама мы шла раба,
#  hypothesis:  мама мы шла рыбу,
#  hypothesis:  мама мы шла раб,
#  hypothesis:  мама мы шла рабу,
#  hypothesis:  мама мы ка рабы,
#  hypothesis:  мама мы ка бабу,
#  hypothesis:  мама мы ка разу,
#  hypothesis:  мама мы ка раба,
#  hypothesis:  мама мы ка рыбу,
#  hypothesis:  мама мы ка раб,
#  hypothesis:  мама мы ка рабу,
#  hypothesis:  мама мы ль рабы,
#  hypothesis:  мама мы ль бабу,
#  hypothesis:  мама мы ль разу,
#  hypothesis:  мама мы ль раба,
#  hypothesis:  мама мы ль рыбу,
#  hypothesis:  мама мы ль раб,
#  hypothesis:  мама мы ль рабу,
#  hypothesis:  мама мы ва рабы,
#  hypothesis:  мама мы ва бабу,
#  hypothesis:  мама мы ва разу,
#  hypothesis:  мама мы ва раба,
#  hypothesis:  мама мы ва рыбу,
#  hypothesis:  мама мы ва раб,
#  hypothesis:  мама мы ва рабу,
#  hypothesis:  мама мы та рабы,
#  hypothesis:  мама мы та бабу,
#  hypothesis:  мама мы та разу,
#  hypothesis:  мама мы та раба,
#  hypothesis:  мама мы та рыбу,
#  hypothesis:  мама мы та раб,
#  hypothesis:  мама мы та рабу,
#  hypothesis:  мама мы л рабы,
#  hypothesis:  мама мы л бабу,
#  hypothesis:  мама мы л разу,
#  hypothesis:  мама мы л раба,
#  hypothesis:  мама мы л рыбу,
#  hypothesis:  мама мы л раб,
#  hypothesis:  мама мы л рабу,
#  hypothesis:  мама мы ма рабы,
#  hypothesis:  мама мы ма бабу,
#  hypothesis:  мама мы ма разу,
#  hypothesis:  мама мы ма раба,
#  hypothesis:  мама мы ма рыбу,
#  hypothesis:  мама мы ма раб,
#  hypothesis:  мама мы ма рабу,
#  hypothesis:  мама мы ела рабы,
#  hypothesis:  мама мы ела бабу,
#  hypothesis:  мама мы ела разу,
#  hypothesis:  мама мы ела раба,
#  hypothesis:  мама мы ела рыбу,
#  hypothesis:  мама мы ела раб,
#  hypothesis:  мама мы ела рабу,
#  hypothesis:  мама мы ля рабы,
#  hypothesis:  мама мы ля бабу,
#  hypothesis:  мама мы ля разу,
#  hypothesis:  мама мы ля раба,
#  hypothesis:  мама мы ля рыбу,
#  hypothesis:  мама мы ля раб,
#  hypothesis:  мама мы ля рабу,
#  hypothesis:  мама мы лаю рабы,
#  hypothesis:  мама мы лаю бабу,
#  hypothesis:  мама мы лаю разу,
#  hypothesis:  мама мы лаю раба,
#  hypothesis:  мама мы лаю рыбу,
#  hypothesis:  мама мы лаю раб,
#  hypothesis:  мама мы лаю рабу,
#  hypothesis:  мама мы ло рабы,
#  hypothesis:  мама мы ло бабу,
#  hypothesis:  мама мы ло разу,
#  hypothesis:  мама мы ло раба,
#  hypothesis:  мама мы ло рыбу,
#  hypothesis:  мама мы ло раб,
#  hypothesis:  мама мы ло рабу,
#  hypothesis:  мама мы ла рабы,
#  hypothesis:  мама мы ла бабу,
#  hypothesis:  мама мы ла разу,
#  hypothesis:  мама мы ла раба,
#  hypothesis:  мама мы ла рыбу,
#  hypothesis:  мама мы ла раб,
#  hypothesis:  мама мы ла рабу,
#  hypothesis:  мама мыла рабы,
#  hypothesis:  мама мыла бабу,
#  hypothesis:  мама мыла разу,
#  hypothesis:  мама мыла раба,
#  hypothesis:  мама мыла рыбу,
#  hypothesis:  мама мыла раб,
#  hypothesis:  мама мыла рабу,
#  hypothesis:  мимо мы на рабы,
#  hypothesis:  мимо мы на бабу,
#  hypothesis:  мимо мы на разу,
#  hypothesis:  мимо мы на раба,
#  hypothesis:  мимо мы на рыбу,
#  hypothesis:  мимо мы на раб,
#  hypothesis:  мимо мы на рабу,
#  hypothesis:  мимо мы за рабы,
#  hypothesis:  мимо мы за бабу,
#  hypothesis:  мимо мы за разу,
#  hypothesis:  мимо мы за раба,
#  hypothesis:  мимо мы за рыбу,
#  hypothesis:  мимо мы за раб,
#  hypothesis:  мимо мы за рабу,
#  hypothesis:  мимо мы а рабы,
#  hypothesis:  мимо мы а бабу,
#  hypothesis:  мимо мы а разу,
#  hypothesis:  мимо мы а раба,
#  hypothesis:  мимо мы а рыбу,
#  hypothesis:  мимо мы а раб,
#  hypothesis:  мимо мы а рабу,
#  hypothesis:  мимо мы да рабы,
#  hypothesis:  мимо мы да бабу,
#  hypothesis:  мимо мы да разу,
#  hypothesis:  мимо мы да раба,
#  hypothesis:  мимо мы да рыбу,
#  hypothesis:  мимо мы да раб,
#  hypothesis:  мимо мы да рабу,
#  hypothesis:  мимо мы ли рабы,
#  hypothesis:  мимо мы ли бабу,
#  hypothesis:  мимо мы ли разу,
#  hypothesis:  мимо мы ли раба,
#  hypothesis:  мимо мы ли рыбу,
#  hypothesis:  мимо мы ли раб,
#  hypothesis:  мимо мы ли рабу,
#  hypothesis:  мимо мы зла рабы,
#  hypothesis:  мимо мы зла бабу,
#  hypothesis:  мимо мы зла разу,
#  hypothesis:  мимо мы зла раба,
#  hypothesis:  мимо мы зла рыбу,
#  hypothesis:  мимо мы зла раб,
#  hypothesis:  мимо мы зла рабу,
#  hypothesis:  мимо мы шла рабы,
#  hypothesis:  мимо мы шла бабу,
#  hypothesis:  мимо мы шла разу,
#  hypothesis:  мимо мы шла раба,
#  hypothesis:  мимо мы шла рыбу,
#  hypothesis:  мимо мы шла раб,
#  hypothesis:  мимо мы шла рабу,
#  hypothesis:  мимо мы ка рабы,
#  hypothesis:  мимо мы ка бабу,
#  hypothesis:  мимо мы ка разу,
#  hypothesis:  мимо мы ка раба,
#  hypothesis:  мимо мы ка рыбу,
#  hypothesis:  мимо мы ка раб,
#  hypothesis:  мимо мы ка рабу,
#  hypothesis:  мимо мы ль рабы,
#  hypothesis:  мимо мы ль бабу,
#  hypothesis:  мимо мы ль разу,
#  hypothesis:  мимо мы ль раба,
#  hypothesis:  мимо мы ль рыбу,
#  hypothesis:  мимо мы ль раб,
#  hypothesis:  мимо мы ль рабу,
#  hypothesis:  мимо мы ва рабы,
#  hypothesis:  мимо мы ва бабу,
#  hypothesis:  мимо мы ва разу,
#  hypothesis:  мимо мы ва раба,
#  hypothesis:  мимо мы ва рыбу,
#  hypothesis:  мимо мы ва раб,
#  hypothesis:  мимо мы ва рабу,
#  hypothesis:  мимо мы та рабы,
#  hypothesis:  мимо мы та бабу,
#  hypothesis:  мимо мы та разу,
#  hypothesis:  мимо мы та раба,
#  hypothesis:  мимо мы та рыбу,
#  hypothesis:  мимо мы та раб,
#  hypothesis:  мимо мы та рабу,
#  hypothesis:  мимо мы л рабы,
#  hypothesis:  мимо мы л бабу,
#  hypothesis:  мимо мы л разу,
#  hypothesis:  мимо мы л раба,
#  hypothesis:  мимо мы л рыбу,
#  hypothesis:  мимо мы л раб,
#  hypothesis:  мимо мы л рабу,
#  hypothesis:  мимо мы ма рабы,
#  hypothesis:  мимо мы ма бабу,
#  hypothesis:  мимо мы ма разу,
#  hypothesis:  мимо мы ма раба,
#  hypothesis:  мимо мы ма рыбу,
#  hypothesis:  мимо мы ма раб,
#  hypothesis:  мимо мы ма рабу,
#  hypothesis:  мимо мы ела рабы,
#  hypothesis:  мимо мы ела бабу,
#  hypothesis:  мимо мы ела разу,
#  hypothesis:  мимо мы ела раба,
#  hypothesis:  мимо мы ела рыбу,
#  hypothesis:  мимо мы ела раб,
#  hypothesis:  мимо мы ела рабу,
#  hypothesis:  мимо мы ля рабы,
#  hypothesis:  мимо мы ля бабу,
#  hypothesis:  мимо мы ля разу,
#  hypothesis:  мимо мы ля раба,
#  hypothesis:  мимо мы ля рыбу,
#  hypothesis:  мимо мы ля раб,
#  hypothesis:  мимо мы ля рабу,
#  hypothesis:  мимо мы лаю рабы,
#  hypothesis:  мимо мы лаю бабу,
#  hypothesis:  мимо мы лаю разу,
#  hypothesis:  мимо мы лаю раба,
#  hypothesis:  мимо мы лаю рыбу,
#  hypothesis:  мимо мы лаю раб,
#  hypothesis:  мимо мы лаю рабу,
#  hypothesis:  мимо мы ло рабы,
#  hypothesis:  мимо мы ло бабу,
#  hypothesis:  мимо мы ло разу,
#  hypothesis:  мимо мы ло раба,
#  hypothesis:  мимо мы ло рыбу,
#  hypothesis:  мимо мы ло раб,
#  hypothesis:  мимо мы ло рабу,
#  hypothesis:  мимо мы ла рабы,
#  hypothesis:  мимо мы ла бабу,
#  hypothesis:  мимо мы ла разу,
#  hypothesis:  мимо мы ла раба,
#  hypothesis:  мимо мы ла рыбу,
#  hypothesis:  мимо мы ла раб,
#  hypothesis:  мимо мы ла рабу,
#  hypothesis:  мимо мыла рабы,
#  hypothesis:  мимо мыла бабу,
#  hypothesis:  мимо мыла разу,
#  hypothesis:  мимо мыла раба,
#  hypothesis:  мимо мыла рыбу,
#  hypothesis:  мимо мыла раб,
#  hypothesis:  мимо мыла рабу,
#  hypothesis:  маме мы на рабы,
#  hypothesis:  маме мы на бабу,
#  hypothesis:  маме мы на разу,
#  hypothesis:  маме мы на раба,
#  hypothesis:  маме мы на рыбу,
#  hypothesis:  маме мы на раб,
#  hypothesis:  маме мы на рабу,
#  hypothesis:  маме мы за рабы,
#  hypothesis:  маме мы за бабу,
#  hypothesis:  маме мы за разу,
#  hypothesis:  маме мы за раба,
#  hypothesis:  маме мы за рыбу,
#  hypothesis:  маме мы за раб,
#  hypothesis:  маме мы за рабу,
#  hypothesis:  маме мы а рабы,
#  hypothesis:  маме мы а бабу,
#  hypothesis:  маме мы а разу,
#  hypothesis:  маме мы а раба,
#  hypothesis:  маме мы а рыбу,
#  hypothesis:  маме мы а раб,
#  hypothesis:  маме мы а рабу,
#  hypothesis:  маме мы да рабы,
#  hypothesis:  маме мы да бабу,
#  hypothesis:  маме мы да разу,
#  hypothesis:  маме мы да раба,
#  hypothesis:  маме мы да рыбу,
#  hypothesis:  маме мы да раб,
#  hypothesis:  маме мы да рабу,
#  hypothesis:  маме мы ли рабы,
#  hypothesis:  маме мы ли бабу,
#  hypothesis:  маме мы ли разу,
#  hypothesis:  маме мы ли раба,
#  hypothesis:  маме мы ли рыбу,
#  hypothesis:  маме мы ли раб,
#  hypothesis:  маме мы ли рабу,
#  hypothesis:  маме мы зла рабы,
#  hypothesis:  маме мы зла бабу,
#  hypothesis:  маме мы зла разу,
#  hypothesis:  маме мы зла раба,
#  hypothesis:  маме мы зла рыбу,
#  hypothesis:  маме мы зла раб,
#  hypothesis:  маме мы зла рабу,
#  hypothesis:  маме мы шла рабы,
#  hypothesis:  маме мы шла бабу,
#  hypothesis:  маме мы шла разу,
#  hypothesis:  маме мы шла раба,
#  hypothesis:  маме мы шла рыбу,
#  hypothesis:  маме мы шла раб,
#  hypothesis:  маме мы шла рабу,
#  hypothesis:  маме мы ка рабы,
#  hypothesis:  маме мы ка бабу,
#  hypothesis:  маме мы ка разу,
#  hypothesis:  маме мы ка раба,
#  hypothesis:  маме мы ка рыбу,
#  hypothesis:  маме мы ка раб,
#  hypothesis:  маме мы ка рабу,
#  hypothesis:  маме мы ль рабы,
#  hypothesis:  маме мы ль бабу,
#  hypothesis:  маме мы ль разу,
#  hypothesis:  маме мы ль раба,
#  hypothesis:  маме мы ль рыбу,
#  hypothesis:  маме мы ль раб,
#  hypothesis:  маме мы ль рабу,
#  hypothesis:  маме мы ва рабы,
#  hypothesis:  маме мы ва бабу,
#  hypothesis:  маме мы ва разу,
#  hypothesis:  маме мы ва раба,
#  hypothesis:  маме мы ва рыбу,
#  hypothesis:  маме мы ва раб,
#  hypothesis:  маме мы ва рабу,
#  hypothesis:  маме мы та рабы,
#  hypothesis:  маме мы та бабу,
#  hypothesis:  маме мы та разу,
#  hypothesis:  маме мы та раба,
#  hypothesis:  маме мы та рыбу,
#  hypothesis:  маме мы та раб,
#  hypothesis:  маме мы та рабу,
#  hypothesis:  маме мы л рабы,
#  hypothesis:  маме мы л бабу,
#  hypothesis:  маме мы л разу,
#  hypothesis:  маме мы л раба,
#  hypothesis:  маме мы л рыбу,
#  hypothesis:  маме мы л раб,
#  hypothesis:  маме мы л рабу,
#  hypothesis:  маме мы ма рабы,
#  hypothesis:  маме мы ма бабу,
#  hypothesis:  маме мы ма разу,
#  hypothesis:  маме мы ма раба,
#  hypothesis:  маме мы ма рыбу,
#  hypothesis:  маме мы ма раб,
#  hypothesis:  маме мы ма рабу,
#  hypothesis:  маме мы ела рабы,
#  hypothesis:  маме мы ела бабу,
#  hypothesis:  маме мы ела разу,
#  hypothesis:  маме мы ела раба,
#  hypothesis:  маме мы ела рыбу,
#  hypothesis:  маме мы ела раб,
#  hypothesis:  маме мы ела рабу,
#  hypothesis:  маме мы ля рабы,
#  hypothesis:  маме мы ля бабу,
#  hypothesis:  маме мы ля разу,
#  hypothesis:  маме мы ля раба,
#  hypothesis:  маме мы ля рыбу,
#  hypothesis:  маме мы ля раб,
#  hypothesis:  маме мы ля рабу,
#  hypothesis:  маме мы лаю рабы,
#  hypothesis:  маме мы лаю бабу,
#  hypothesis:  маме мы лаю разу,
#  hypothesis:  маме мы лаю раба,
#  hypothesis:  маме мы лаю рыбу,
#  hypothesis:  маме мы лаю раб,
#  hypothesis:  маме мы лаю рабу,
#  hypothesis:  маме мы ло рабы,
#  hypothesis:  маме мы ло бабу,
#  hypothesis:  маме мы ло разу,
#  hypothesis:  маме мы ло раба,
#  hypothesis:  маме мы ло рыбу,
#  hypothesis:  маме мы ло раб,
#  hypothesis:  маме мы ло рабу,
#  hypothesis:  маме мы ла рабы,
#  hypothesis:  маме мы ла бабу,
#  hypothesis:  маме мы ла разу,
#  hypothesis:  маме мы ла раба,
#  hypothesis:  маме мы ла рыбу,
#  hypothesis:  маме мы ла раб,
#  hypothesis:  маме мы ла рабу,
#  hypothesis:  маме мыла рабы,
#  hypothesis:  маме мыла бабу,
#  hypothesis:  маме мыла разу,
#  hypothesis:  маме мыла раба,
#  hypothesis:  маме мыла рыбу,
#  hypothesis:  маме мыла раб,
#  hypothesis:  маме мыла рабу,
#  hypothesis:  мамо мы на рабы,
#  hypothesis:  мамо мы на бабу,
#  hypothesis:  мамо мы на разу,
#  hypothesis:  мамо мы на раба,
#  hypothesis:  мамо мы на рыбу,
#  hypothesis:  мамо мы на раб,
#  hypothesis:  мамо мы на рабу,
#  hypothesis:  мамо мы за рабы,
#  hypothesis:  мамо мы за бабу,
#  hypothesis:  мамо мы за разу,
#  hypothesis:  мамо мы за раба,
#  hypothesis:  мамо мы за рыбу,
#  hypothesis:  мамо мы за раб,
#  hypothesis:  мамо мы за рабу,
#  hypothesis:  мамо мы а рабы,
#  hypothesis:  мамо мы а бабу,
#  hypothesis:  мамо мы а разу,
#  hypothesis:  мамо мы а раба,
#  hypothesis:  мамо мы а рыбу,
#  hypothesis:  мамо мы а раб,
#  hypothesis:  мамо мы а рабу,
#  hypothesis:  мамо мы да рабы,
#  hypothesis:  мамо мы да бабу,
#  hypothesis:  мамо мы да разу,
#  hypothesis:  мамо мы да раба,
#  hypothesis:  мамо мы да рыбу,
#  hypothesis:  мамо мы да раб,
#  hypothesis:  мамо мы да рабу,
#  hypothesis:  мамо мы ли рабы,
#  hypothesis:  мамо мы ли бабу,
#  hypothesis:  мамо мы ли разу,
#  hypothesis:  мамо мы ли раба,
#  hypothesis:  мамо мы ли рыбу,
#  hypothesis:  мамо мы ли раб,
#  hypothesis:  мамо мы ли рабу,
#  hypothesis:  мамо мы зла рабы,
#  hypothesis:  мамо мы зла бабу,
#  hypothesis:  мамо мы зла разу,
#  hypothesis:  мамо мы зла раба,
#  hypothesis:  мамо мы зла рыбу,
#  hypothesis:  мамо мы зла раб,
#  hypothesis:  мамо мы зла рабу,
#  hypothesis:  мамо мы шла рабы,
#  hypothesis:  мамо мы шла бабу,
#  hypothesis:  мамо мы шла разу,
#  hypothesis:  мамо мы шла раба,
#  hypothesis:  мамо мы шла рыбу,
#  hypothesis:  мамо мы шла раб,
#  hypothesis:  мамо мы шла рабу,
#  hypothesis:  мамо мы ка рабы,
#  hypothesis:  мамо мы ка бабу,
#  hypothesis:  мамо мы ка разу,
#  hypothesis:  мамо мы ка раба,
#  hypothesis:  мамо мы ка рыбу,
#  hypothesis:  мамо мы ка раб,
#  hypothesis:  мамо мы ка рабу,
#  hypothesis:  мамо мы ль рабы,
#  hypothesis:  мамо мы ль бабу,
#  hypothesis:  мамо мы ль разу,
#  hypothesis:  мамо мы ль раба,
#  hypothesis:  мамо мы ль рыбу,
#  hypothesis:  мамо мы ль раб,
#  hypothesis:  мамо мы ль рабу,
#  hypothesis:  мамо мы ва рабы,
#  hypothesis:  мамо мы ва бабу,
#  hypothesis:  мамо мы ва разу,
#  hypothesis:  мамо мы ва раба,
#  hypothesis:  мамо мы ва рыбу,
#  hypothesis:  мамо мы ва раб,
#  hypothesis:  мамо мы ва рабу,
#  hypothesis:  мамо мы та рабы,
#  hypothesis:  мамо мы та бабу,
#  hypothesis:  мамо мы та разу,
#  hypothesis:  мамо мы та раба,
#  hypothesis:  мамо мы та рыбу,
#  hypothesis:  мамо мы та раб,
#  hypothesis:  мамо мы та рабу,
#  hypothesis:  мамо мы л рабы,
#  hypothesis:  мамо мы л бабу,
#  hypothesis:  мамо мы л разу,
#  hypothesis:  мамо мы л раба,
#  hypothesis:  мамо мы л рыбу,
#  hypothesis:  мамо мы л раб,
#  hypothesis:  мамо мы л рабу,
#  hypothesis:  мамо мы ма рабы,
#  hypothesis:  мамо мы ма бабу,
#  hypothesis:  мамо мы ма разу,
#  hypothesis:  мамо мы ма раба,
#  hypothesis:  мамо мы ма рыбу,
#  hypothesis:  мамо мы ма раб,
#  hypothesis:  мамо мы ма рабу,
#  hypothesis:  мамо мы ела рабы,
#  hypothesis:  мамо мы ела бабу,
#  hypothesis:  мамо мы ела разу,
#  hypothesis:  мамо мы ела раба,
#  hypothesis:  мамо мы ела рыбу,
#  hypothesis:  мамо мы ела раб,
#  hypothesis:  мамо мы ела рабу,
#  hypothesis:  мамо мы ля рабы,
#  hypothesis:  мамо мы ля бабу,
#  hypothesis:  мамо мы ля разу,
#  hypothesis:  мамо мы ля раба,
#  hypothesis:  мамо мы ля рыбу,
#  hypothesis:  мамо мы ля раб,
#  hypothesis:  мамо мы ля рабу,
#  hypothesis:  мамо мы лаю рабы,
#  hypothesis:  мамо мы лаю бабу,
#  hypothesis:  мамо мы лаю разу,
#  hypothesis:  мамо мы лаю раба,
#  hypothesis:  мамо мы лаю рыбу,
#  hypothesis:  мамо мы лаю раб,
#  hypothesis:  мамо мы лаю рабу,
#  hypothesis:  мамо мы ло рабы,
#  hypothesis:  мамо мы ло бабу,
#  hypothesis:  мамо мы ло разу,
#  hypothesis:  мамо мы ло раба,
#  hypothesis:  мамо мы ло рыбу,
#  hypothesis:  мамо мы ло раб,
#  hypothesis:  мамо мы ло рабу,
#  hypothesis:  мамо мы ла рабы,
#  hypothesis:  мамо мы ла бабу,
#  hypothesis:  мамо мы ла разу,
#  hypothesis:  мамо мы ла раба,
#  hypothesis:  мамо мы ла рыбу,
#  hypothesis:  мамо мы ла раб,
#  hypothesis:  мамо мы ла рабу,
#  hypothesis:  мамо мыла рабы,
#  hypothesis:  мамо мыла бабу,
#  hypothesis:  мамо мыла разу,
#  hypothesis:  мамо мыла раба,
#  hypothesis:  мамо мыла рыбу,
#  hypothesis:  мамо мыла раб,
#  hypothesis:  мамо мыла рабу]

# %%
#######################################################################
hypotheses_hub = HypothesesHub()
for current_token_idx, each_tok in enumerate(analysis_dict['tokenized_input_sentence']):
    if current_token_idx==0:
        # skip the first token which is <s>
        continue
    if current_token_idx==len(analysis_dict['tokenized_input_sentence'])-1:
        # skip the last token which is </s>
        continue
    print(each_tok)
    #  suffixes_hypotheses = data_analysis_dict['word_substitutions_candidates'].filter(start_idx=current_token_idx)
    suffixes_hypotheses = SCAnalysisDictManager.filter_by_start_index(
        data_anal_dict=analysis_dict, start_index=current_token_idx)
    print("suffixes_hypotheses")
    print(suffixes_hypotheses)
    # TODO implement method:
    hypotheses_hub = hypotheses_hub.fork_for_suffixes_segment_hypotheses(suffixes_hypotheses)
    print(len(hypotheses_hub))
    # TODO prune hypotheses that has finish_index==current_token_idx, but dont prune hypotheses that are longer
# TODO implement method:
the_best_sentence_hypothesis = hypotheses_hub.find_top_k(top_k=1)
# Out:
# мамо
# suffixes_hypotheses
# [{'tok_idx': 1, 'top_k_candidates': [{'advantage': 0.0, 'token_str': 'мамо'}]}]
# each_s_hypothesis.finish_idx < suffixes_start_idx
# 1
# мы
# suffixes_hypotheses
# [{'tok_idx': 2, 'top_k_candidates': [{'advantage': 0.0, 'token_str': 'мы'}]}, {'tok_idx': (2, 3), 'tok_idx_start': 2, 'tok_idx_fin': 3, 'top_k_candidates': [{'token_str': 'мыла', 'token_merges': 1, 'error_score': -4.0, 'lm_scores_list': array([-5.04645906, -7.16744132]), 'base_scores': array([[-6.6675347 , -6.32782808],
#        [-6.6675347 , -6.32782808]]), 'summated_base_scores': array([-13.3350694 , -12.65565617]), 'advantage': 5.7768251961428625}]}]
# each_s_hypothesis.finish_idx < suffixes_start_idx
# 2
# ла
# suffixes_hypotheses
# [{'tok_idx': 3, 'top_k_candidates': [{'advantage': 3.9098788682098444, 'token_str': 'на'}, {'advantage': 2.869433134510696, 'token_str': 'за'}, {'advantage': 1.609125288265215, 'token_str': 'а'}, {'advantage': 0.5913022780445818, 'token_str': 'да'}, {'advantage': 0.5347466175017583, 'token_str': 'ли'}, {'advantage': 8.881784197001252e-16, 'token_str': 'ла'}]}]
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx > suffixes_start_idx
# 7
# рабу
# suffixes_hypotheses
# [{'tok_idx': 4, 'top_k_candidates': [{'advantage': 0.0, 'token_str': 'рабу'}]}]
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# each_s_hypothesis.finish_idx < suffixes_start_idx
# 7

# %%
# for each_hypo in the_best_sentence_hypothesis:
#     print(each_hypo.calc_advantage_score())
    
sorted(the_best_sentence_hypothesis, key=lambda x: x.calc_advantage_score(), reverse=True)
# Out:
# [hypothesis:  мало мы на рабы,
#  hypothesis:  мало мы на бабу,
#  hypothesis:  мало мы на разу,
#  hypothesis:  мало мы на раба,
#  hypothesis:  мама мы на рабы,
#  hypothesis:  мало мы на рыбу,
#  hypothesis:  мимо мы на рабы,
#  hypothesis:  мама мы на бабу,
#  hypothesis:  мама мы на разу,
#  hypothesis:  мало мы на раб,
#  hypothesis:  мало мы за рабы,
#  hypothesis:  мама мы на раба,
#  hypothesis:  мимо мы на бабу,
#  hypothesis:  мимо мы на разу,
#  hypothesis:  мимо мы на раба,
#  hypothesis:  мама мы на рыбу,
#  hypothesis:  мало мы за бабу,
#  hypothesis:  мало мы на рабу,
#  hypothesis:  мало мы за разу,
#  hypothesis:  маме мы на рабы,
#  hypothesis:  мало мы за раба,
#  hypothesis:  мамо мы на рабы,
#  hypothesis:  мимо мы на рыбу,
#  hypothesis:  маме мы на бабу,
#  hypothesis:  мама мы на раб,
#  hypothesis:  мама мы за рабы,
#  hypothesis:  мало мы за рыбу,
#  hypothesis:  маме мы на разу,
#  hypothesis:  мамо мы на бабу,
#  hypothesis:  мамо мы на разу,
#  hypothesis:  маме мы на раба,
#  hypothesis:  мамо мы на раба,
#  hypothesis:  мимо мы на раб,
#  hypothesis:  мимо мы за рабы,
#  hypothesis:  мама мы за бабу,
#  hypothesis:  мама мы на рабу,
#  hypothesis:  мама мы за разу,
#  hypothesis:  маме мы на рыбу,
#  hypothesis:  мало мы за раб,
#  hypothesis:  мама мы за раба,
#  hypothesis:  мамо мы на рыбу,
#  hypothesis:  мало мыла рабы,
#  hypothesis:  мимо мы за бабу,
#  hypothesis:  мимо мы на рабу,
#  hypothesis:  мимо мы за разу,
#  hypothesis:  мало мы а рабы,
#  hypothesis:  мимо мы за раба,
#  hypothesis:  мама мы за рыбу,
#  hypothesis:  мало мы за рабу,
#  hypothesis:  мало мыла бабу,
#  hypothesis:  маме мы на раб,
#  hypothesis:  маме мы за рабы,
#  hypothesis:  мало мыла разу,
#  hypothesis:  мамо мы на раб,
#  hypothesis:  мамо мы за рабы,
#  hypothesis:  мало мыла раба,
#  hypothesis:  мало мы а бабу,
#  hypothesis:  мимо мы за рыбу,
#  hypothesis:  мало мы а разу,
#  hypothesis:  маме мы за бабу,
#  hypothesis:  мало мы а раба,
#  hypothesis:  мама мы за раб,
#  hypothesis:  маме мы на рабу,
#  hypothesis:  маме мы за разу,
#  hypothesis:  мамо мы за бабу,
#  hypothesis:  мама мыла рабы,
#  hypothesis:  мало мыла рыбу,
#  hypothesis:  мамо мы на рабу,
#  hypothesis:  мамо мы за разу,
#  hypothesis:  маме мы за раба,
#  hypothesis:  мамо мы за раба,
#  hypothesis:  мама мы а рабы,
#  hypothesis:  мало мы а рыбу,
#  hypothesis:  мимо мы за раб,
#  hypothesis:  мама мы за рабу,
#  hypothesis:  мимо мыла рабы,
#  hypothesis:  мама мыла бабу,
#  hypothesis:  маме мы за рыбу,
#  hypothesis:  мама мыла разу,
#  hypothesis:  мамо мы за рыбу,
#  hypothesis:  мало мыла раб,
#  hypothesis:  мама мыла раба,
#  hypothesis:  мимо мы а рабы,
#  hypothesis:  мама мы а бабу,
#  hypothesis:  мимо мы за рабу,
#  hypothesis:  мама мы а разу,
#  hypothesis:  мимо мыла бабу,
#  hypothesis:  мало мы да рабы,
#  hypothesis:  мало мы а раб,
#  hypothesis:  мама мы а раба,
#  hypothesis:  мимо мыла разу,
#  hypothesis:  мало мы ли рабы,
#  hypothesis:  мимо мыла раба,
#  hypothesis:  мама мыла рыбу,
#  hypothesis:  мимо мы а бабу,
#  hypothesis:  мало мыла рабу,
#  hypothesis:  маме мы за раб,
#  hypothesis:  мимо мы а разу,
#  hypothesis:  маме мыла рабы,
#  hypothesis:  мамо мы за раб,
#  hypothesis:  мало мы да бабу,
#  hypothesis:  мимо мы а раба,
#  hypothesis:  мама мы а рыбу,
#  hypothesis:  мамо мыла рабы,
#  hypothesis:  мало мы ли бабу,
#  hypothesis:  мало мы а рабу,
#  hypothesis:  мало мы да разу,
#  hypothesis:  мимо мыла рыбу,
#  hypothesis:  маме мы а рабы,
#  hypothesis:  мало мы ли разу,
#  hypothesis:  мало мы да раба,
#  hypothesis:  мамо мы а рабы,
#  hypothesis:  маме мы за рабу,
#  hypothesis:  мало мы ли раба,
#  hypothesis:  маме мыла бабу,
#  hypothesis:  мама мыла раб,
#  hypothesis:  мамо мы за рабу,
#  hypothesis:  мимо мы а рыбу,
#  hypothesis:  маме мыла разу,
#  hypothesis:  мамо мыла бабу,
#  hypothesis:  мамо мыла разу,
#  hypothesis:  маме мыла раба,
#  hypothesis:  мама мы да рабы,
#  hypothesis:  маме мы а бабу,
#  hypothesis:  мало мы да рыбу,
#  hypothesis:  мама мы а раб,
#  hypothesis:  мамо мыла раба,
#  hypothesis:  мама мы ли рабы,
#  hypothesis:  маме мы а разу,
#  hypothesis:  мамо мы а бабу,
#  hypothesis:  мало мы ли рыбу,
#  hypothesis:  мимо мыла раб,
#  hypothesis:  мамо мы а разу,
#  hypothesis:  маме мы а раба,
#  hypothesis:  мама мыла рабу,
#  hypothesis:  мамо мы а раба,
#  hypothesis:  маме мыла рыбу,
#  hypothesis:  мимо мы да рабы,
#  hypothesis:  мама мы да бабу,
#  hypothesis:  мимо мы а раб,
#  hypothesis:  мамо мыла рыбу,
#  hypothesis:  мимо мы ли рабы,
#  hypothesis:  мама мы ли бабу,
#  hypothesis:  мама мы а рабу,
#  hypothesis:  мама мы да разу,
#  hypothesis:  мама мы ли разу,
#  hypothesis:  маме мы а рыбу,
#  hypothesis:  мимо мыла рабу,
#  hypothesis:  мало мы да раб,
#  hypothesis:  мама мы да раба,
#  hypothesis:  мало мы ли раб,
#  hypothesis:  мама мы ли раба,
#  hypothesis:  мамо мы а рыбу,
#  hypothesis:  мимо мы да бабу,
#  hypothesis:  мимо мы ли бабу,
#  hypothesis:  мимо мы а рабу,
#  hypothesis:  мимо мы да разу,
#  hypothesis:  маме мыла раб,
#  hypothesis:  мимо мы ли разу,
#  hypothesis:  мимо мы да раба,
#  hypothesis:  мама мы да рыбу,
#  hypothesis:  мамо мыла раб,
#  hypothesis:  мало мы да рабу,
#  hypothesis:  мимо мы ли раба,
#  hypothesis:  мама мы ли рыбу,
#  hypothesis:  мало мы ли рабу,
#  hypothesis:  маме мы да рабы,
#  hypothesis:  маме мы а раб,
#  hypothesis:  маме мы ли рабы,
#  hypothesis:  мамо мы да рабы,
#  hypothesis:  мамо мы а раб,
#  hypothesis:  мамо мы ли рабы,
#  hypothesis:  мимо мы да рыбу,
#  hypothesis:  маме мыла рабу,
#  hypothesis:  мимо мы ли рыбу,
#  hypothesis:  мамо мыла рабу,
#  hypothesis:  маме мы да бабу,
#  hypothesis:  мама мы да раб,
#  hypothesis:  маме мы ли бабу,
#  hypothesis:  маме мы а рабу,
#  hypothesis:  маме мы да разу,
#  hypothesis:  мамо мы да бабу,
#  hypothesis:  мама мы ли раб,
#  hypothesis:  маме мы ли разу,
#  hypothesis:  мамо мы ли бабу,
#  hypothesis:  мамо мы а рабу,
#  hypothesis:  мамо мы да разу,
#  hypothesis:  маме мы да раба,
#  hypothesis:  мамо мы ли разу,
#  hypothesis:  маме мы ли раба,
#  hypothesis:  мамо мы да раба,
#  hypothesis:  мимо мы да раб,
#  hypothesis:  мамо мы ли раба,
#  hypothesis:  мама мы да рабу,
#  hypothesis:  мимо мы ли раб,
#  hypothesis:  мама мы ли рабу,
#  hypothesis:  маме мы да рыбу,
#  hypothesis:  маме мы ли рыбу,
#  hypothesis:  мамо мы да рыбу,
#  hypothesis:  мамо мы ли рыбу,
#  hypothesis:  мимо мы да рабу,
#  hypothesis:  мимо мы ли рабу,
#  hypothesis:  мало мы зла рабы,
#  hypothesis:  мало мы шла рабы,
#  hypothesis:  маме мы да раб,
#  hypothesis:  мало мы ка рабы,
#  hypothesis:  маме мы ли раб,
#  hypothesis:  мамо мы да раб,
#  hypothesis:  мамо мы ли раб,
#  hypothesis:  мало мы зла бабу,
#  hypothesis:  мало мы зла разу,
#  hypothesis:  мало мы шла бабу,
#  hypothesis:  маме мы да рабу,
#  hypothesis:  мало мы ка бабу,
#  hypothesis:  мало мы зла раба,
#  hypothesis:  мало мы шла разу,
#  hypothesis:  маме мы ли рабу,
#  hypothesis:  мамо мы да рабу,
#  hypothesis:  мало мы ка разу,
#  hypothesis:  мало мы шла раба,
#  hypothesis:  мамо мы ли рабу,
#  hypothesis:  мало мы ка раба,
#  hypothesis:  мама мы зла рабы,
#  hypothesis:  мало мы зла рыбу,
#  hypothesis:  мало мы ль рабы,
#  hypothesis:  мама мы шла рабы,
#  hypothesis:  мало мы шла рыбу,
#  hypothesis:  мама мы ка рабы,
#  hypothesis:  мало мы ка рыбу,
#  hypothesis:  мало мы ва рабы,
#  hypothesis:  мимо мы зла рабы,
#  hypothesis:  мама мы зла бабу,
#  hypothesis:  мало мы та рабы,
#  hypothesis:  мама мы зла разу,
#  hypothesis:  мимо мы шла рабы,
#  hypothesis:  мало мы ль бабу,
#  hypothesis:  мама мы шла бабу,
#  hypothesis:  мимо мы ка рабы,
#  hypothesis:  мало мы зла раб,
#  hypothesis:  мама мы ка бабу,
#  hypothesis:  мама мы зла раба,
#  hypothesis:  мало мы ль разу,
#  hypothesis:  мама мы шла разу,
#  hypothesis:  мама мы ка разу,
#  hypothesis:  мало мы л рабы,
#  hypothesis:  мало мы ль раба,
#  hypothesis:  мало мы шла раб,
#  hypothesis:  мама мы шла раба,
#  hypothesis:  мало мы ва бабу,
#  hypothesis:  мимо мы зла бабу,
#  hypothesis:  мало мы та бабу,
#  hypothesis:  мало мы ка раб,
#  hypothesis:  мама мы ка раба,
#  hypothesis:  мало мы ва разу,
#  hypothesis:  мимо мы зла разу,
#  hypothesis:  мало мы та разу,
#  hypothesis:  мимо мы шла бабу,
#  hypothesis:  мало мы ва раба,
#  hypothesis:  мимо мы ка бабу,
#  hypothesis:  мимо мы зла раба,
#  hypothesis:  мама мы зла рыбу,
#  hypothesis:  мимо мы шла разу,
#  hypothesis:  мало мы та раба,
#  hypothesis:  мало мы зла рабу,
#  hypothesis:  мама мы ль рабы,
#  hypothesis:  мимо мы ка разу,
#  hypothesis:  мало мы ма рабы,
#  hypothesis:  мало мы ль рыбу,
#  hypothesis:  мало мы л бабу,
#  hypothesis:  мимо мы шла раба,
#  hypothesis:  мама мы шла рыбу,
#  hypothesis:  маме мы зла рабы,
#  hypothesis:  мало мы ела рабы,
#  hypothesis:  мало мы шла рабу,
#  hypothesis:  мимо мы ка раба,
#  hypothesis:  мама мы ка рыбу,
#  hypothesis:  мало мы л разу,
#  hypothesis:  мамо мы зла рабы,
#  hypothesis:  мало мы ка рабу,
#  hypothesis:  маме мы шла рабы,
#  hypothesis:  мама мы ва рабы,
#  hypothesis:  мало мы л раба,
#  hypothesis:  мало мы ва рыбу,
#  hypothesis:  мама мы та рабы,
#  hypothesis:  маме мы ка рабы,
#  hypothesis:  мимо мы зла рыбу,
#  hypothesis:  мамо мы шла рабы,
#  hypothesis:  мало мы та рыбу,
#  hypothesis:  мимо мы ль рабы,
#  hypothesis:  мамо мы ка рабы,
#  hypothesis:  мама мы ль бабу,
#  hypothesis:  мало мы ма бабу,
#  hypothesis:  мимо мы шла рыбу,
#  hypothesis:  мало мы ля рабы,
#  hypothesis:  маме мы зла бабу,
#  hypothesis:  мама мы зла раб,
#  hypothesis:  мама мы ль разу,
#  hypothesis:  мимо мы ка рыбу,
#  hypothesis:  мало мы лаю рабы,
#  hypothesis:  мало мы ела бабу,
#  hypothesis:  мало мы ма разу,
#  hypothesis:  маме мы зла разу,
#  hypothesis:  мамо мы зла бабу,
#  hypothesis:  маме мы шла бабу,
#  hypothesis:  мама мы л рабы,
#  hypothesis:  мало мы ль раб,
#  hypothesis:  мало мы ела разу,
#  hypothesis:  мама мы ль раба,
#  hypothesis:  мимо мы ва рабы,
#  hypothesis:  мама мы шла раб,
#  hypothesis:  мало мы ма раба,
#  hypothesis:  мама мы ва бабу,
#  hypothesis:  мало мы л рыбу,
#  hypothesis:  мимо мы та рабы,
#  hypothesis:  мамо мы зла разу,
#  hypothesis:  мама мы та бабу,
#  hypothesis:  маме мы ка бабу,
#  hypothesis:  маме мы зла раба,
#  hypothesis:  маме мы шла разу,
#  hypothesis:  мамо мы шла бабу,
#  hypothesis:  мама мы ка раб,
#  hypothesis:  мало мы ела раба,
#  hypothesis:  мама мы ва разу,
#  hypothesis:  мимо мы ль бабу,
#  hypothesis:  мама мы та разу,
#  hypothesis:  маме мы ка разу,
#  hypothesis:  мамо мы ка бабу,
#  hypothesis:  мамо мы зла раба,
#  hypothesis:  мамо мы шла разу,
#  hypothesis:  маме мы шла раба,
#  hypothesis:  мало мы ля бабу,
#  hypothesis:  мало мы ва раб,
#  hypothesis:  мама мы ва раба,
#  hypothesis:  мимо мы зла раб,
#  hypothesis:  мимо мы ль разу,
#  hypothesis:  мамо мы ка разу,
#  hypothesis:  мало мы та раб,
#  hypothesis:  мама мы та раба,
#  hypothesis:  маме мы ка раба,
#  hypothesis:  мало мы лаю бабу,
#  hypothesis:  мамо мы шла раба,
#  hypothesis:  мало мы ля разу,
#  hypothesis:  мама мы зла рабу,
#  hypothesis:  мама мы ма рабы,
#  hypothesis:  мимо мы л рабы,
#  hypothesis:  мимо мы ль раба,
#  hypothesis:  мама мы ль рыбу,
#  hypothesis:  мамо мы ка раба,
#  hypothesis:  мимо мы шла раб,
#  hypothesis:  мама мы л бабу,
#  hypothesis:  мало мы ло рабы,
#  hypothesis:  мало мы лаю разу,
#  hypothesis:  мало мы ма рыбу,
#  hypothesis:  мимо мы ва бабу,
#  hypothesis:  мимо мы та бабу,
#  hypothesis:  мало мы ля раба,
#  hypothesis:  мало мы ль рабу,
#  hypothesis:  маме мы зла рыбу,
#  hypothesis:  мама мы ела рабы,
#  hypothesis:  мама мы шла рабу,
#  hypothesis:  мимо мы ка раб,
#  hypothesis:  мама мы л разу,
#  hypothesis:  мало мы ела рыбу,
#  hypothesis:  мимо мы ва разу,
#  hypothesis:  мало мы лаю раба,
#  hypothesis:  маме мы ль рабы,
#  hypothesis:  мама мы ка рабу,
#  hypothesis:  мимо мы та разу,
#  hypothesis:  мамо мы зла рыбу,
#  hypothesis:  маме мы шла рыбу,
#  hypothesis:  мало мы л раб,
#  hypothesis:  мама мы л раба,
#  hypothesis:  мимо мы ва раба,
#  hypothesis:  мама мы ва рыбу,
#  hypothesis:  мамо мы ль рабы,
#  hypothesis:  мимо мы та раба,
#  hypothesis:  мама мы та рыбу,
#  hypothesis:  маме мы ка рыбу,
#  hypothesis:  мамо мы шла рыбу,
#  hypothesis:  мало мы ва рабу,
#  hypothesis:  мимо мы зла рабу,
#  hypothesis:  мало мы та рабу,
#  hypothesis:  мимо мы ма рабы,
#  hypothesis:  мало мы ла рабы,
#  hypothesis:  мимо мы ль рыбу,
#  hypothesis:  мама мы ма бабу,
#  hypothesis:  мамо мы ка рыбу,
#  hypothesis:  мимо мы л бабу,
#  hypothesis:  маме мы ва рабы,
#  hypothesis:  мама мы ля рабы,
#  hypothesis:  мало мы ло бабу,
#  hypothesis:  маме мы та рабы,
#  hypothesis:  мало мы ля рыбу,
#  hypothesis:  мимо мы ела рабы,
#  hypothesis:  мимо мы шла рабу,
#  hypothesis:  мама мы лаю рабы,
#  hypothesis:  мама мы ела бабу,
#  hypothesis:  мама мы ма разу,
#  hypothesis:  мимо мы л разу,
#  hypothesis:  мамо мы ва рабы,
#  hypothesis:  мало мы лаю рыбу,
#  hypothesis:  мало мы ло разу,
#  hypothesis:  мамо мы та рабы,
#  hypothesis:  мимо мы ка рабу,
#  hypothesis:  маме мы ль бабу,
#  hypothesis:  мама мы ль раб,
#  hypothesis:  мама мы ела разу,
#  hypothesis:  мало мы ма раб,
#  hypothesis:  мама мы ма раба,
#  hypothesis:  мимо мы л раба,
#  hypothesis:  мама мы л рыбу,
#  hypothesis:  мимо мы ва рыбу,
#  hypothesis:  мало мы ло раба,
#  hypothesis:  маме мы зла раб,
#  hypothesis:  маме мы ль разу,
#  hypothesis:  мамо мы ль бабу,
#  hypothesis:  мимо мы та рыбу,
#  hypothesis:  мало мы л рабу,
#  hypothesis:  мало мы ела раб,
#  hypothesis:  мама мы ела раба,
#  hypothesis:  мамо мы зла раб,
#  hypothesis:  мамо мы ль разу,
#  hypothesis:  маме мы л рабы,
#  hypothesis:  мимо мы ма бабу,
#  hypothesis:  маме мы ль раба,
#  hypothesis:  мало мы ла бабу,
#  hypothesis:  маме мы шла раб,
#  hypothesis:  мимо мы ля рабы,
#  hypothesis:  маме мы ва бабу,
#  hypothesis:  мама мы ля бабу,
#  hypothesis:  мама мы ва раб,
#  hypothesis:  маме мы та бабу,
#  hypothesis:  мимо мы лаю рабы,
#  hypothesis:  мимо мы ела бабу,
#  hypothesis:  мама мы та раб,
#  hypothesis:  маме мы ка раб,
#  hypothesis:  мимо мы ма разу,
#  hypothesis:  мамо мы л рабы,
#  hypothesis:  мамо мы ль раба,
#  hypothesis:  мало мы ла разу,
#  hypothesis:  мама мы лаю бабу,
#  hypothesis:  мамо мы шла раб,
#  hypothesis:  маме мы ва разу,
#  hypothesis:  мамо мы ва бабу,
#  hypothesis:  мама мы ля разу,
#  hypothesis:  маме мы та разу,
#  hypothesis:  мамо мы та бабу,
#  hypothesis:  мимо мы ль раб,
#  hypothesis:  мимо мы ела разу,
#  hypothesis:  мамо мы ка раб,
#  hypothesis:  мама мы ло рабы,
#  hypothesis:  мама мы лаю разу,
#  hypothesis:  мимо мы ма раба,
#  hypothesis:  мама мы ма рыбу,
#  hypothesis:  мимо мы л рыбу,
#  hypothesis:  мало мы ла раба,
#  hypothesis:  мамо мы ва разу,
#  hypothesis:  мало мы ло рыбу,
#  hypothesis:  маме мы ва раба,
#  hypothesis:  мало мы ля раб,
#  hypothesis:  мама мы ля раба,
#  hypothesis:  мама мы ль рабу,
#  hypothesis:  мамо мы та разу,
#  hypothesis:  мало мы ма рабу,
#  hypothesis:  маме мы та раба,
#  hypothesis:  мимо мы ела раба,
#  hypothesis:  мама мы ела рыбу,
#  hypothesis:  мало мы лаю раб,
#  hypothesis:  мама мы лаю раба,
#  hypothesis:  маме мы зла рабу,
#  hypothesis:  мамо мы ва раба,
#  hypothesis:  маме мы ма рабы,
#  hypothesis:  мало мы ела рабу,
#  hypothesis:  маме мы ль рыбу,
#  hypothesis:  мамо мы та раба,
#  hypothesis:  маме мы л бабу,
#  hypothesis:  мама мы л раб,
#  hypothesis:  мимо мы ля бабу,
#  hypothesis:  мимо мы ва раб,
#  hypothesis:  мамо мы зла рабу,
#  hypothesis:  маме мы ела рабы,
#  hypothesis:  маме мы шла рабу,
#  hypothesis:  мимо мы та раб,
#  hypothesis:  мамо мы ма рабы,
#  hypothesis:  мамо мы ль рыбу,
#  hypothesis:  мимо мы лаю бабу,
#  hypothesis:  маме мы л разу,
#  hypothesis:  мамо мы л бабу,
#  hypothesis:  мама мы ва рабу,
#  hypothesis:  мимо мы ля разу,
#  hypothesis:  мама мы та рабу,
#  hypothesis:  маме мы ка рабу,
#  hypothesis:  мамо мы ела рабы,
#  hypothesis:  мамо мы шла рабу,
#  hypothesis:  мама мы ла рабы,
#  hypothesis:  мимо мы ло рабы,
#  hypothesis:  мимо мы лаю разу,
#  hypothesis:  мимо мы ма рыбу,
#  hypothesis:  мамо мы л разу,
#  hypothesis:  мало мы ла рыбу,
#  hypothesis:  мама мы ло бабу,
#  hypothesis:  маме мы л раба,
#  hypothesis:  маме мы ва рыбу,
#  hypothesis:  мимо мы ля раба,
#  hypothesis:  мама мы ля рыбу,
#  hypothesis:  мимо мы ль рабу,
#  hypothesis:  мамо мы ка рабу,
#  hypothesis:  маме мы та рыбу,
#  hypothesis:  мимо мы ела рыбу,
#  hypothesis:  мимо мы лаю раба,
#  hypothesis:  мало мы ля рабу,
#  hypothesis:  мама мы лаю рыбу,
#  hypothesis:  мама мы ло разу,
#  hypothesis:  мамо мы л раба,
#  hypothesis:  мамо мы ва рыбу,
#  hypothesis:  маме мы ма бабу,
#  hypothesis:  мамо мы та рыбу,
#  hypothesis:  мало мы лаю рабу,
#  hypothesis:  мама мы ма раб,
#  hypothesis:  маме мы ля рабы,
#  hypothesis:  мимо мы л раб,
#  hypothesis:  мало мы ло раб,
#  hypothesis:  мама мы ло раба,
#  hypothesis:  маме мы лаю рабы,
#  hypothesis:  маме мы ела бабу,
#  hypothesis:  маме мы ма разу,
#  hypothesis:  мама мы л рабу,
#  hypothesis:  мамо мы ма бабу,
#  hypothesis:  мимо мы ва рабу,
#  hypothesis:  мама мы ела раб,
#  hypothesis:  мамо мы ля рабы,
#  hypothesis:  мимо мы та рабу,
#  hypothesis:  мимо мы ла рабы,
#  hypothesis:  маме мы ль раб,
#  hypothesis:  маме мы ела разу,
#  hypothesis:  мамо мы лаю рабы,
#  hypothesis:  мамо мы ела бабу,
#  hypothesis:  мама мы ла бабу,
#  hypothesis:  мамо мы ма разу,
#  hypothesis:  маме мы ма раба,
#  hypothesis:  мимо мы ло бабу,
#  hypothesis:  маме мы л рыбу,
#  hypothesis:  мимо мы ля рыбу,
#  hypothesis:  мамо мы ль раб,
#  hypothesis:  мамо мы ела разу,
#  hypothesis:  мама мы ла разу,
#  hypothesis:  маме мы ела раба,
#  hypothesis:  мимо мы лаю рыбу,
#  hypothesis:  мимо мы ло разу,
#  hypothesis:  мамо мы ма раба,
#  hypothesis:  мамо мы л рыбу,
#  hypothesis:  мимо мы ма раб,
#  hypothesis:  мало мы ла раб,
#  hypothesis:  мамо мы ела раба,
#  hypothesis:  мама мы ла раба,
#  hypothesis:  маме мы ля бабу,
#  hypothesis:  маме мы ва раб,
#  hypothesis:  мимо мы ло раба,
#  hypothesis:  мама мы ло рыбу,
#  hypothesis:  мама мы ля раб,
#  hypothesis:  маме мы та раб,
#  hypothesis:  мама мы ма рабу,
#  hypothesis:  мимо мы л рабу,
#  hypothesis:  маме мы лаю бабу,
#  hypothesis:  мимо мы ела раб,
#  hypothesis:  мало мы ло рабу,
#  hypothesis:  мама мы лаю раб,
#  hypothesis:  маме мы ля разу,
#  hypothesis:  мамо мы ля бабу,
#  hypothesis:  мамо мы ва раб,
#  hypothesis:  мама мы ела рабу,
#  hypothesis:  мамо мы та раб,
#  hypothesis:  мимо мы ла бабу,
#  hypothesis:  маме мы ло рабы,
#  hypothesis:  маме мы лаю разу,
#  hypothesis:  мамо мы лаю бабу,
#  hypothesis:  маме мы ма рыбу,
#  hypothesis:  мамо мы ля разу,
#  hypothesis:  маме мы ля раба,
#  hypothesis:  маме мы ль рабу,
#  hypothesis:  мимо мы ла разу,
#  hypothesis:  маме мы ела рыбу,
#  hypothesis:  мамо мы ло рабы,
#  hypothesis:  мамо мы лаю разу,
#  hypothesis:  мамо мы ма рыбу,
#  hypothesis:  маме мы лаю раба,
#  hypothesis:  мамо мы ля раба,
#  hypothesis:  мамо мы ль рабу,
#  hypothesis:  мамо мы ела рыбу,
#  hypothesis:  мимо мы ла раба,
#  hypothesis:  мама мы ла рыбу,
#  hypothesis:  маме мы л раб,
#  hypothesis:  мамо мы лаю раба,
#  hypothesis:  мимо мы ло рыбу,
#  hypothesis:  мимо мы ля раб,
#  hypothesis:  мимо мы ма рабу,
#  hypothesis:  мало мы ла рабу,
#  hypothesis:  маме мы ва рабу,
#  hypothesis:  мимо мы лаю раб,
#  hypothesis:  мама мы ля рабу,
#  hypothesis:  мамо мы л раб,
#  hypothesis:  маме мы та рабу,
#  hypothesis:  мимо мы ела рабу,
#  hypothesis:  маме мы ла рабы,
#  hypothesis:  мама мы лаю рабу,
#  hypothesis:  мамо мы ва рабу,
#  hypothesis:  маме мы ло бабу,
#  hypothesis:  мама мы ло раб,
#  hypothesis:  маме мы ля рыбу,
#  hypothesis:  мамо мы та рабу,
#  hypothesis:  мамо мы ла рабы,
#  hypothesis:  маме мы лаю рыбу,
#  hypothesis:  маме мы ло разу,
#  hypothesis:  мамо мы ло бабу,
#  hypothesis:  мамо мы ля рыбу,
#  hypothesis:  маме мы ма раб,
#  hypothesis:  мимо мы ла рыбу,
#  hypothesis:  мамо мы лаю рыбу,
#  hypothesis:  мамо мы ло разу,
#  hypothesis:  маме мы ло раба,
#  hypothesis:  маме мы л рабу,
#  hypothesis:  маме мы ела раб,
#  hypothesis:  мамо мы ма раб,
#  hypothesis:  мимо мы ля рабу,
#  hypothesis:  мамо мы ло раба,
#  hypothesis:  мимо мы лаю рабу,
#  hypothesis:  маме мы ла бабу,
#  hypothesis:  мамо мы л рабу,
#  hypothesis:  мамо мы ела раб,
#  hypothesis:  мама мы ла раб,
#  hypothesis:  мимо мы ло раб,
#  hypothesis:  маме мы ла разу,
#  hypothesis:  мамо мы ла бабу,
#  hypothesis:  мама мы ло рабу,
#  hypothesis:  мамо мы ла разу,
#  hypothesis:  маме мы ла раба,
#  hypothesis:  маме мы ло рыбу,
#  hypothesis:  маме мы ля раб,
#  hypothesis:  маме мы ма рабу,
#  hypothesis:  маме мы лаю раб,
#  hypothesis:  мамо мы ла раба,
#  hypothesis:  мамо мы ло рыбу,
#  hypothesis:  мамо мы ля раб,
#  hypothesis:  маме мы ела рабу,
#  hypothesis:  мамо мы ма рабу,
#  hypothesis:  мимо мы ла раб,
#  hypothesis:  мамо мы лаю раб,
#  hypothesis:  мамо мы ела рабу,
#  hypothesis:  мама мы ла рабу,
#  hypothesis:  мимо мы ло рабу,
#  hypothesis:  маме мы ла рыбу,
#  hypothesis:  маме мы ля рабу,
#  hypothesis:  мамо мы ла рыбу,
#  hypothesis:  маме мы лаю рабу,
#  hypothesis:  мамо мы ля рабу,
#  hypothesis:  маме мы ло раб,
#  hypothesis:  мимо мы ла рабу,
#  hypothesis:  мамо мы лаю рабу,
#  hypothesis:  мамо мы ло раб,
#  hypothesis:  маме мы ла раб,
#  hypothesis:  маме мы ло рабу,
#  hypothesis:  мамо мы ла раб,
#  hypothesis:  мамо мы ло рабу,
#  hypothesis:  маме мы ла рабу,
#  hypothesis:  мамо мы ла рабу]

# %%
elmo_data.shape
# Out:
# (6, 2, 1000000)

# %%
# estimate score of the merged token
# {'tok_idx': (2, 3),
#    'tok_idx_start': 2,
#    'tok_idx_fin': 3,
#    'top_k_candidates': [{'token_str': 'мыла',
#      'token_merges': 1,
#      'error_score': -4.0}]}]}

np.log10(elmo_data[1, :, 49657:49667])
# Out:
# array([[-7.89935879, -6.68768751, -8.26770615, -8.44233911, -6.12489386,
#         -5.66360093, -7.97351025, -8.19241068, -7.67558967, -7.89791163],
#        [-6.14079886, -7.52041743, -8.23220287, -7.93148408, -7.7780586 ,
#         -6.86853707, -6.82381484, -8.01061398, -7.75469577, -9.07290786]])

# %%
в_индкс, неизв = elmo40in.lm.get_word_idx_or_unk("мыла")

# %%
в_индкс, неизв
# Out:
# (49657, False)

# %%
# Out:
# array([-4.99906474, -6.26263737])

# %%
# Out:
# array([-6.23646029, -5.22346355])

# %%
# from deeppavlov.models.spelling_correction.levenshtein.searcher_component import LevenshteinSearcherComponent

from dp_components.levenshtein_searcher_component import LevenshteinSearcherComponent

# %%
# default_alhpabet = ['-', '.', '/', 'a', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'm', 'n', 
#                     'o', 'p', 'r', 's', 't', 'u', 'v',
#                     'а', 'б', 'в', 'г', 'д', 'е', 'ж', 'з', 'и', 'й', 'к', 'л', 'м', 'н',
#                      'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'ш', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я']

# %%
DATA_PATH = "/home/alx/Cloud/spell_corr/py_spelling_corrector/data/"

# %%
words_dict = []
with open(DATA_PATH + "compreno_wordforms.txt", "r") as dict_file:
    words_dict = dict_file.read().splitlines()

# %%
len(words_dict)
# Out:
# 3460401

# %%
"привет" in words_dict
# Out:
# True

# %%
words_dict[2000001]
# Out:
# 'перераспределяемыми'

# %%
# lsc = LevenshteinSearcherComponent(words=words_dict, alphabet=default_alhpabet)

# %%
lsc = LevenshteinSearcherComponent(words=words_dict)

# %%
lsc.searcher.alphabet
# Out:
# ['$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '-',
#  '.',
#  '/',
#  '0',
#  '1',
#  '2',
#  '3',
#  'a',
#  'c',
#  'd',
#  'e',
#  'f',
#  'g',
#  'h',
#  'i',
#  'k',
#  'm',
#  'n',
#  'o',
#  'p',
#  'r',
#  's',
#  't',
#  'u',
#  'v',
#  '£',
#  '§',
#  '°',
#  '²',
#  '³',
#  '·',
#  'а',
#  'б',
#  'в',
#  'г',
#  'д',
#  'е',
#  'ж',
#  'з',
#  'и',
#  'й',
#  'к',
#  'л',
#  'м',
#  'н',
#  'о',
#  'п',
#  'р',
#  'с',
#  'т',
#  'у',
#  'ф',
#  'х',
#  'ц',
#  'ч',
#  'ш',
#  'щ',
#  'ъ',
#  'ы',
#  'ь',
#  'э',
#  'ю',
#  'я']

# %%
lsc.searcher.alphabet
# Out:
# ['$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '-',
#  '.',
#  '/',
#  '0',
#  '1',
#  '2',
#  '3',
#  'a',
#  'c',
#  'd',
#  'e',
#  'f',
#  'g',
#  'h',
#  'i',
#  'k',
#  'm',
#  'n',
#  'o',
#  'p',
#  'r',
#  's',
#  't',
#  'u',
#  'v',
#  '£',
#  '§',
#  '°',
#  '²',
#  '³',
#  '·',
#  'а',
#  'б',
#  'в',
#  'г',
#  'д',
#  'е',
#  'ж',
#  'з',
#  'и',
#  'й',
#  'к',
#  'л',
#  'м',
#  'н',
#  'о',
#  'п',
#  'р',
#  'с',
#  'т',
#  'у',
#  'ф',
#  'х',
#  'ц',
#  'ч',
#  'ш',
#  'щ',
#  'ъ',
#  'ы',
#  'ь',
#  'э',
#  'ю',
#  'я']

# %%
lsc([["где нибудь"]])
# Out:
# [[[(-4.0, 'где-нибудь'), (-8.0, 'где нибудь')]]]

# %%
lsc([["вор ота"]])
# Out:
# [[[(-4.0, 'ворота'), (-8.0, 'вор ота')]]]

# %%
# custom:

# %%
lsc([["врта"]])
# Out:
# [[[(-3.800969465807842, 'арта'),
#    (-3.87206451061939, 'вота'),
#    (-4.0, 'врат'),
#    (-4.0, 'в та'),
#    (-4.0, 'врата'),
#    (-4.0, 'врыта'),
#    (-4.0, 'рта'),
#    (-4.0, 'варта'),
#    (-4.0, 'верта'),
#    (-4.0, 'вирта'),
#    (-4.0, 'ворта'),
#    (-4.0, 'вюрта'),
#    (-4.0, 'в рта'),
#    (0, 'врта')]]]

# %%
lsc([["врта"]])
# Out:
# [[[(-3.800969465807842, 'арта'),
#    (-3.87206451061939, 'вота'),
#    (-4.0, 'врат'),
#    (-4.0, 'врата'),
#    (-4.0, 'врыта'),
#    (-4.0, 'рта'),
#    (-4.0, 'варта'),
#    (-4.0, 'верта'),
#    (-4.0, 'вирта'),
#    (-4.0, 'ворта'),
#    (-4.0, 'вюрта'),
#    (0, 'врта')]]]

# %%
# deep pavlov:

# %%
lsc([["врта"]])
# Out:
# [[[(-4.0, 'врат'),
#    (-4.0, 'враа'),
#    (-4.0, 'вата'),
#    (-4.0, 'вета'),
#    (-4.0, 'вита'),
#    (-4.0, 'вота'),
#    (-4.0, 'в та'),
#    (-4.0, 'врата'),
#    (-4.0, 'врыта'),
#    (-4.0, 'рта'),
#    (-4.0, 'арта'),
#    (-4.0, 'орта'),
#    (-4.0, 'эрта'),
#    (-4.0, 'юрта'),
#    (-4.0, 'варта'),
#    (-4.0, 'верта'),
#    (-4.0, 'вирта'),
#    (-4.0, 'ворта'),
#    (-4.0, 'вюрта'),
#    (-4.0, 'в рта'),
#    (-8.0, 'врта')]]]

# %%
lsc.searcher.transducer.operation_costs.keys()
# Out:
# dict_keys(['', '$', '%', '&', "'", '(', ')', '-', '.', '/', '0', '1', '2', '3', 'a', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k', 'm', 'n', 'o', 'p', 'r', 's', 't', 'u', 'v', '£', '§', '°', '²', '³', '·', 'а', 'б', 'в', 'г', 'д', 'е', 'ж', 'з', 'и', 'й', 'к', 'л', 'м', 'н', 'о', 'п', 'р', 'с', 'т', 'у', 'ф', 'х', 'ц', 'ч', 'ш', 'щ', 'ъ', 'ы', 'ь', 'э', 'ю', 'я', '$%', '$&', "$'", '$(', '$)', '$-', '$.', '$/', '$0', '$1', '$2', '$3', '$a', '$c', '$d', '$e', '$f', '$g', '$h', '$i', '$k', '$m', '$n', '$o', '$p', '$r', '$s', '$t', '$u', '$v', '$£', '$§', '$°', '$²', '$³', '$·', '$а', '$б', '$в', '$г', '$д', '$е', '$ж', '$з', '$и', '$й', '$к', '$л', '$м', '$н', '$о', '$п', '$р', '$с', '$т', '$у', '$ф', '$х', '$ц', '$ч', '$ш', '$щ', '$ъ', '$ы', '$ь', '$э', '$ю', '$я', '%$', '%&', "%'", '%(', '%)', '%-', '%.', '%/', '%0', '%1', '%2', '%3', '%a', '%c', '%d', '%e', '%f', '%g', '%h', '%i', '%k', '%m', '%n', '%o', '%p', '%r', '%s', '%t', '%u', '%v', '%£', '%§', '%°', '%²', '%³', '%·', '%а', '%б', '%в', '%г', '%д', '%е', '%ж', '%з', '%и', '%й', '%к', '%л', '%м', '%н', '%о', '%п', '%р', '%с', '%т', '%у', '%ф', '%х', '%ц', '%ч', '%ш', '%щ', '%ъ', '%ы', '%ь', '%э', '%ю', '%я', '&$', '&%', "&'", '&(', '&)', '&-', '&.', '&/', '&0', '&1', '&2', '&3', '&a', '&c', '&d', '&e', '&f', '&g', '&h', '&i', '&k', '&m', '&n', '&o', '&p', '&r', '&s', '&t', '&u', '&v', '&£', '&§', '&°', '&²', '&³', '&·', '&а', '&б', '&в', '&г', '&д', '&е', '&ж', '&з', '&и', '&й', '&к', '&л', '&м', '&н', '&о', '&п', '&р', '&с', '&т', '&у', '&ф', '&х', '&ц', '&ч', '&ш', '&щ', '&ъ', '&ы', '&ь', '&э', '&ю', '&я', "'$", "'%", "'&", "'(", "')", "'-", "'.", "'/", "'0", "'1", "'2", "'3", "'a", "'c", "'d", "'e", "'f", "'g", "'h", "'i", "'k", "'m", "'n", "'o", "'p", "'r", "'s", "'t", "'u", "'v", "'£", "'§", "'°", "'²", "'³", "'·", "'а", "'б", "'в", "'г", "'д", "'е", "'ж", "'з", "'и", "'й", "'к", "'л", "'м", "'н", "'о", "'п", "'р", "'с", "'т", "'у", "'ф", "'х", "'ц", "'ч", "'ш", "'щ", "'ъ", "'ы", "'ь", "'э", "'ю", "'я", '($', '(%', '(&', "('", '()', '(-', '(.', '(/', '(0', '(1', '(2', '(3', '(a', '(c', '(d', '(e', '(f', '(g', '(h', '(i', '(k', '(m', '(n', '(o', '(p', '(r', '(s', '(t', '(u', '(v', '(£', '(§', '(°', '(²', '(³', '(·', '(а', '(б', '(в', '(г', '(д', '(е', '(ж', '(з', '(и', '(й', '(к', '(л', '(м', '(н', '(о', '(п', '(р', '(с', '(т', '(у', '(ф', '(х', '(ц', '(ч', '(ш', '(щ', '(ъ', '(ы', '(ь', '(э', '(ю', '(я', ')$', ')%', ')&', ")'", ')(', ')-', ').', ')/', ')0', ')1', ')2', ')3', ')a', ')c', ')d', ')e', ')f', ')g', ')h', ')i', ')k', ')m', ')n', ')o', ')p', ')r', ')s', ')t', ')u', ')v', ')£', ')§', ')°', ')²', ')³', ')·', ')а', ')б', ')в', ')г', ')д', ')е', ')ж', ')з', ')и', ')й', ')к', ')л', ')м', ')н', ')о', ')п', ')р', ')с', ')т', ')у', ')ф', ')х', ')ц', ')ч', ')ш', ')щ', ')ъ', ')ы', ')ь', ')э', ')ю', ')я', '-$', '-%', '-&', "-'", '-(', '-)', '-.', '-/', '-0', '-1', '-2', '-3', '-a', '-c', '-d', '-e', '-f', '-g', '-h', '-i', '-k', '-m', '-n', '-o', '-p', '-r', '-s', '-t', '-u', '-v', '-£', '-§', '-°', '-²', '-³', '-·', '-а', '-б', '-в', '-г', '-д', '-е', '-ж', '-з', '-и', '-й', '-к', '-л', '-м', '-н', '-о', '-п', '-р', '-с', '-т', '-у', '-ф', '-х', '-ц', '-ч', '-ш', '-щ', '-ъ', '-ы', '-ь', '-э', '-ю', '-я', '.$', '.%', '.&', ".'", '.(', '.)', '.-', './', '.0', '.1', '.2', '.3', '.a', '.c', '.d', '.e', '.f', '.g', '.h', '.i', '.k', '.m', '.n', '.o', '.p', '.r', '.s', '.t', '.u', '.v', '.£', '.§', '.°', '.²', '.³', '.·', '.а', '.б', '.в', '.г', '.д', '.е', '.ж', '.з', '.и', '.й', '.к', '.л', '.м', '.н', '.о', '.п', '.р', '.с', '.т', '.у', '.ф', '.х', '.ц', '.ч', '.ш', '.щ', '.ъ', '.ы', '.ь', '.э', '.ю', '.я', '/$', '/%', '/&', "/'", '/(', '/)', '/-', '/.', '/0', '/1', '/2', '/3', '/a', '/c', '/d', '/e', '/f', '/g', '/h', '/i', '/k', '/m', '/n', '/o', '/p', '/r', '/s', '/t', '/u', '/v', '/£', '/§', '/°', '/²', '/³', '/·', '/а', '/б', '/в', '/г', '/д', '/е', '/ж', '/з', '/и', '/й', '/к', '/л', '/м', '/н', '/о', '/п', '/р', '/с', '/т', '/у', '/ф', '/х', '/ц', '/ч', '/ш', '/щ', '/ъ' ...

# %%
lsc([["съездеть"]])
# Out:
# [[[(-4.0, 'съезде ь'), (-4.0, 'съездить'), (-8.0, 'съездеть')]]]

# %%
lsc([["съездеть"]])
# Out:
# [[[(-2.0, 'съездить'), (0, 'съездеть')]]]

# %%
lsc([["расжился"]])
# Out:
# [[[(-4.0, 'растился'),
#    (-4.0, 'расшился'),
#    (-4.0, 'разжился'),
#    (-4.0, 'р сжился'),
#    (-4.0, 'ра сжился'),
#    (-8.0, 'расжился')]]]

# %%
lsc([["припораты"]])
# Out:
# [[[(-4.0, 'приораты'), (-8.0, 'припораты')]]]

# %%
lsc([["профессиональная","профессиональнаякарьера","карьера"]])
# Out:
# [[[(-0.0, 'профессиональная'),
#    (-4.0, 'профессиональна'),
#    (-4.0, 'профессиональна я'),
#    (-4.0, 'профессионал ная')],
#   [(-4.0, 'профессиональна карьера'),
#    (-4.0, 'профессиональная карьера'),
#    (-8.0, 'профессиональнаякарьера')],
#   [(-0.0, 'карьера'),
#    (-4.0, 'карьер'),
#    (-4.0, 'карьере'),
#    (-4.0, 'карьеро'),
#    (-4.0, 'карьеру'),
#    (-4.0, 'карьеры'),
#    (-4.0, 'карьерам'),
#    (-4.0, 'карьерах'),
#    (-4.0, 'карьер а'),
#    (-4.0, 'карь ра'),
#    (-4.0, 'карвера'),
#    (-4.0, 'каргера'),
#    (-4.0, 'кардера'),
#    (-4.0, 'карпера'),
#    (-4.0, 'каррера'),
#    (-4.0, 'картера'),
#    (-4.0, 'кархера'),
#    (-4.0, 'карцера'),
#    (-4.0, 'кар ера'),
#    (-4.0, 'карь ера'),
#    (-4.0, 'каррьера'),
#    (-4.0, 'курьера'),
#    (-4.0, 'барьера')]]]

# %%
lsc([["все","смешалось","кони","люди"]])
# Out:
# [[[(-0.0, 'все'),
#    (-4.0, 'вес'),
#    (-4.0, 'вс'),
#    (-4.0, 'всю'),
#    (-4.0, 'вся'),
#    (-4.0, 'всей'),
#    (-4.0, 'всем'),
#    (-4.0, 'всех'),
#    (-4.0, 'всею'),
#    (-4.0, 'всея'),
#    (-4.0, 'ве'),
#    (-4.0, 'вее'),
#    (-4.0, 'вне'),
#    (-4.0, 'вое'),
#    (-4.0, 'вше'),
#    (-4.0, 'вые'),
#    (-4.0, 'вье'),
#    (-4.0, 'вэе'),
#    (-4.0, 'в е'),
#    (-4.0, 'всуе'),
#    (-4.0, 'вс е'),
#    (-4.0, 'се'),
#    (-4.0, 'асе'),
#    (-4.0, 'есе'),
#    (-4.0, 'исе'),
#    (-4.0, 'осе'),
#    (-4.0, 'псе'),
#    (-4.0, 'усе'),
#    (-4.0, 'юсе'),
#    (-4.0, 'ясе'),
#    (-4.0, 'васе'),
#    (-4.0, 'весе'),
#    (-4.0, 'висе'),
#    (-4.0, 'восе'),
#    (-4.0, 'высе'),
#    (-4.0, 'в се'),
#    (-4.0, 'ивсе'),
#    (-4.0, 'овсе')],
#   [(-0.0, 'смешалось'),
#    (-4.0, 'смешало ь'),
#    (-4.0, 'смешалась'),
#    (-4.0, 'смешались'),
#    (-4.0, 'смеша ось'),
#    (-4.0, 'смешал ось'),
#    (-4.0, 'смешилось'),
#    (-4.0, 'смеша лось'),
#    (-4.0, 'смежалось'),
#    (-4.0, 'смекалось'),
#    (-4.0, 'сметалось'),
#    (-4.0, 'смещалось'),
#    (-4.0, 'свешалось'),
#    (-4.0, 'мешалось'),
#    (-4.0, 'вмешалось'),
#    (-4.0, 'с мешалось')],
#   [(-0.0, 'кони'),
#    (-4.0, 'кон'),
#    (-4.0, 'кона'),
#    (-4.0, 'конг'),
#    (-4.0, 'коне'),
#    (-4.0, 'конн'),
#    (-4.0, 'коно'),
#    (-4.0, 'конт'),
#    (-4.0, 'кону'),
#    (-4.0, 'конф'),
#    (-4.0, 'конц'),
#    (-4.0, 'коны'),
#    (-4.0, 'конь'),
#    (-4.0, 'коню'),
#    (-4.0, 'коня'),
#    (-4.0, 'коник'),
#    (-4.0, 'конин'),
#    (-4.0, 'кои'),
#    (-4.0, 'коби'),
#    (-4.0, 'кови'),
#    (-4.0, 'коди'),
#    (-4.0, 'кожи'),
#    (-4.0, 'кози'),
#    (-4.0, 'коки'),
#    (-4.0, 'коли'),
#    (-4.0, 'коми'),
#    (-4.0, 'копи'),
#    (-4.0, 'кори'),
#    (-4.0, 'коси'),
#    (-4.0, 'коти'),
#    (-4.0, 'коуи'),
#    (-4.0, 'кофи'),
#    (-4.0, 'кохи'),
#    (-4.0, 'коши'),
#    (-4.0, 'ко и'),
#    (-4.0, 'конги'),
#    (-4.0, 'конди'),
#    (-4.0, 'конки'),
#    (-4.0, 'конли'),
#    (-4.0, 'конни'),
#    (-4.0, 'конти'),
#    (-4.0, 'конфи'),
#    (-4.0, 'кончи'),
#    (-4.0, 'коньи'),
#    (-4.0, 'кон и'),
#    (-4.0, 'кани'),
#    (-4.0, 'кини'),
#    (-4.0, 'куни'),
#    (-4.0, 'к ни'),
#    (-4.0, 'козни'),
#    (-4.0, 'кокни'),
#    (-4.0, 'копни'),
#    (-4.0, 'корни'),
#    (-4.0, 'коуни'),
#    (-4.0, 'кочни'),
#    (-4.0, 'ко ни'),
#    (-4.0, 'они'),
#    (-4.0, 'бони'),
#    (-4.0, 'вони'),
#    (-4.0, 'гони'),
#    (-4.0, 'дони'),
#    (-4.0, 'лони'),
#    (-4.0, 'мони'),
#    (-4.0, 'пони'),
#    (-4.0, 'рони'),
#    (-4.0, 'сони'),
#    (-4.0, 'тони'),
#    (-4.0, 'фони'),
#    (-4.0, 'хони'),
#    (-4.0, 'шони'),
#    (-4.0, 'клони'),
#    (-4.0, 'к они'),
#    (-4.0, 'окони')],
#   [(-0.0, 'люди'),
#    (-4.0, 'люд'),
#    (-4.0, 'люда'),
#    (-4.0, 'люде'),
#    (-4.0, 'людк'),
#    (-4.0, 'людо'),
#    (-4.0, 'люду'),
#    (-4.0, 'люды'),
#    (-4.0, 'людин'),
#    (-4.0, 'люи'),
#    (-4.0, 'люби'),
#    (-4.0, 'люки'),
#    (-4.0, 'люси'),
#    (-4.0, 'лю и'),
#    (-4.0, 'людки'),
#    (-4.0, 'люд и'),
#    (-4.0, 'леди'),
#    (-4.0, 'лиди'),
#    (-4.0, 'лоди'),
#    (-4.0, 'луди'),
#    (-4.0, 'л ди'),
#    (-4.0, 'лю ди'),
#    (-4.0, 'блюди')]]]

# %%
lsc([["смешалысь"]])[0][0]
# Out:
# [(-4.0, 'смешалась'),
#  (-4.0, 'смешались'),
#  (-4.0, 'смешалось'),
#  (-8.0, 'смешалысь')]

# %%
lsc([["ктонибудь"]])[0][0]
# Out:
# [(-4.0, 'кто-нибудь'), (-8.0, 'ктонибудь')]

# %%
lsc([["вобщем"]])[0][0]
# Out:
# [(-2.593812284330876, 'воющем'),
#  (-4.0, 'общем'),
#  (-4.0, 'в общем'),
#  (0, 'вобщем')]
